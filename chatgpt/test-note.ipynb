# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Career\QWork\chatgpt\products.csv')
df
# Out:
#       product_id                                              Title  Reviews
# 0              1  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...        0  \
# 1              2  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...        0
# 2              3  PXN K30 Gaming TKL Battledock Mechanical Keybo...        0
# 3              4  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...        0
# 4              5  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...        0
# ...          ...                                                ...      ...
# 1816        1817  BEST SELLER 1STPLAYER Mechanical Gaming Keyboa...        0
# 1817        1818  PROMO Powerlogic Armageddon MKA 9C RGB Mechani...        0
# 1818        1819  Terunik Powerlogic Armageddon MKA 5R RGB Mecha...        0
# 1819        1820  Terunik Powerlogic Armageddon MKA 11R RGB Mech...        0
# 1820        1821  BEST SELLER Cougar Mechanical Gaming Keyboard ...        0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 31 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   product_id                                       1821 non-null   int64
#  1   Title                                            1821 non-null   object
#  2   Reviews                                          1821 non-null   int64
#  3   Sold                                             1821 non-null   float64
#  4   Original Price                                   1821 non-null   int64
#  5   Description                                      1821 non-null   object
#  6   Product URL                                      1821 non-null   object
#  7   Brand (Category)                                 1807 non-null   object
#  8   Material casing (Category)                       1292 non-null   object
# ...

# %%
store_df = pd.read_csv('D:\Career\QWork\chatgpt\stores.csv', delimiter= ';')

# %%
store_df
# Out:
#      store_id             Store Name      Store City  Positive Feedback
# 0           1             uneed shop   Jakarta Utara               6516  \
# 1           2          Gaming Distro   Jakarta Pusat               1216
# 2           3          Store Pinokio  Kab. Tangerang               3132
# 3           4  Distributor_Aksesoris   Jakarta Pusat               4253
# 4           5               Starcomp          Sleman               5693
# ..        ...                    ...             ...                ...
# 246       247               Toko Ane     Kab. Bekasi                 15
# 247       248              bruceshop   Jakarta Utara                  0
# 248       249           Andrew Wisqi   Jakarta Pusat                  1
# 249       250            kadutt shop   Jakarta Barat               7464
# 250       251                  panji   Jakarta Timur                 21
#
#      Total Feedback
# 0              6541
# 1              1275
# 2              3136
# ...

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   store_id           251 non-null    int64
#  1   Store Name         251 non-null    object
#  2   Store City         251 non-null    object
#  3   Positive Feedback  251 non-null    int64
#  4   Total Feedback     251 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 9.9+ KB
