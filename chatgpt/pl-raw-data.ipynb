# %% [markdown]
# ### Step 1: Loading and Preprocessing Data

# %% [markdown]
# **Loading Libraries:**
# We import necessary libraries such as Pandas for data manipulation, OpenAI for utilizing the GPT-3 model, JSON for handling JSON data, and dotenv for loading environment variables.

# %%
import pandas as pd
import openai
import json
from dotenv import dotenv_values

# %% [markdown]
# **Loading API Key:** We load the OpenAI API key from the environment variables stored in a `.env` file.

# %%
config = dotenv_values(".env")

# %%
openai.api_key = config["OPEN_API_KEY"]

# %% [markdown]
# **Defining Function for Description Extraction:** We define a function `get_description_details` to extract specific details from product titles and descriptions using the OpenAI GPT-3 model.

# %%
def get_description_details(title, description):
    respon_gpt = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user",
        "content": f"""
        {title}
        {description}

        Please provide me with these points based on the title and description above, and fill them according to their format. Make all the languages English, including the keys, and format them as a dictionary with keys and values. If the data is not available, just use a '-' dash

        Brand (Category)
        Material casing (Category)
        Underglow RGB (Yes/No)
        South-facing RGB switch (Yes/No)
        Hot-swappable (5 pin) (Yes/No)
        Compatibility with mechanical switch (Category)
        Magic FN key (Yes/No)
        Software customization (Yes/No)
        Keycap profile (Category)
        Color options (Category)
        Switch options (Category)
        Keyboard layout (Category)
        Number of keys (Number)
        Dimensions (Length) (millimeters)
        Dimensions (Width) (millimeters)
        Dimensions (Height) (millimeters)
        Weight (grams)
        Pre-lubed stabilizer (Yes/No)
        Include damper foam (Yes/No)
        Detachable Type-C (Yes/No)
        Onboard memory (Yes/No)
        Anti-ghosting (Yes/No)
        RGB Per-Key (Yes/No)
        Battery capacity (mAh)
        """}
        ],
        # max_tokens=350, 
        max_tokens=700 # for title_error
    )

    response = respon_gpt.choices[0].message.content

    json_start = response.find('{')
    json_end = response.rfind('}') + 1

    # Periksa apakah respons berupa JSON yang valid
    if json_start != -1 and json_end != -1:
        response_str = response[json_start:json_end]
        
        # Coba parse JSON
        try:
            response_dict = json.loads(response_str)
            return response_dict
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}. Skipping to next row.")
            return None
    else:
        print("No valid JSON found in response. Skipping to next row.")
        return None

# %% [markdown]
# **Loading Dataset:** We read the dataset containing mechanical keyboard information from a CSV file scraped data into a Pandas DataFrame. After that, we iterate through each row in the DataFrame to process the descriptions and extract relevant details using the defined function.

# %%
# Baca file CSV
df = pd.read_csv('D:\Career\QWork\scrapy\\bukalapak\mechanical-keboard-1.csv')

# Hapus baris yang tidak memiliki judul
df.dropna(subset=['Title'], inplace=True)

# Iterasi setiap baris
for index, row in df.iterrows():
    title = row['Title']
    description = row['Description']
    
    # Proses deskripsi untuk mendapatkan poin-poin
    # max_tokens = 350
    details = get_description_details(title, description)

    # Jika details adalah None, cetak nomor baris
    if details is None:
        print(f"Skipping row {index + 1} - Title: {title}")
        continue
    
    # Update dataframe dengan poin-poin yang dihasilkan
    for key, value in details.items():
        df.at[index, key] = value

    # Print pesan untuk setiap item yang merupakan kelipatan 50
    if (index + 1) % 50 == 0:
        print(f"Item {index+1} processed")

print(f"Total {index + 1} rows processed")
# Out:
# Error decoding JSON: Expecting ',' delimiter: line 17 column 45 (char 634). Skipping to next row.
# Skipping row 30 - Title: Keychron K3 v2 Gateron Low Profile WHITE Wireless Mechanical Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 17 column 45 (char 565). Skipping to next row.
# Skipping row 33 - Title: Keychron K6 Non Backlight Aluminum Frame Wireless Mechanical Keyboard
# Item 150 processed
# Error decoding JSON: Expecting ',' delimiter: line 15 column 31 (char 535). Skipping to next row.
# Skipping row 164 - Title: Rexus Keyboard Numeric Mechanical Daxa M22
# Error decoding JSON: Expecting property name enclosed in double quotes: line 26 column 1 (char 772). Skipping to next row.
# Skipping row 175 - Title: Keyboard Gaming Logitech G413 SE TKL Mechanical Tactile Backlit
# Item 200 processed
# Item 250 processed
# Item 300 processed
# Item 350 processed
# Item 400 processed
# Error decoding JSON: Expecting ',' delimiter: line 15 column 49 (char 639). Skipping to next row.
# Skipping row 410 - Title: LEOPOLD FC660M PD WHITE TWO TONE CHERRY MX BROWN MECHANICAL KEYBOARD FC660MN/EWPD
# Error decoding JSON: Expecting ',' delimiter: line 14 column 35 (char 569). Skipping to next row.
# Skipping row 431 - Title: Keyboard Gaming Mechanical Komic Kg-Mk288 - New Led - Original
# Item 450 processed
# Error decoding JSON: Expecting ',' delimiter: line 15 column 32 (char 486). Skipping to next row.
# Skipping row 477 - Title: Keyboard Gaming Mechanical Redragon Macro RGB SURYA K563RGB
# Item 500 processed
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 449). Skipping to next row.
# Skipping row 528 - Title: Keyboard Gaming Mechanical AULA S-2022 BLACK -New LED- Macro Software
# Item 550 processed
# Item 600 processed
# Error decoding JSON: Expecting property name enclosed in double quotes: line 25 column 33 (char 857). Skipping to next row.
# Skipping row 607 - Title: Fantech MK857 Maxfit61 FROST WIRELESS Mechanical Gaming Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 14 column 30 (char 496). Skipping to next row.
# Skipping row 613 - Title: Keyboard Gaming Mechanical Aula S-2022 Macro Keyboard Aula S 2022
# Item 650 processed
# Error decoding JSON: Expecting ',' delimiter: line 17 column 45 (char 595). Skipping to next row.
# Skipping row 671 - Title: Keychron K3 Non-Backlight Ultra-Slim Wireless Mechanical Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 17 column 30 (char 567). Skipping to next row.
# Skipping row 699 - Title: Leopold FC750R Charcoal Blue Mechanical Gaming Keyboard
# Item 700 processed
# Item 750 processed
# Error decoding JSON: Expecting ',' delimiter: line 17 column 45 (char 807). Skipping to next row.
# Skipping row 763 - Title: Keychron K3 Ultra Slim Mechanical Keyboard Low Profile Optical Hotswap
# Error decoding JSON: Expecting value: line 15 column 43 (char 472). Skipping to next row.
# Skipping row 772 - Title: E-YOOSO Z-19 MECHANICAL KEYBOARD 94 KEY Black Grey RGB
# Error decoding JSON: Expecting ',' delimiter: line 15 column 32 (char 486). Skipping to next row.
# Skipping row 783 - Title: Keyboard Gaming Mechanical Hotswap Outemu Red Switch TKL RGB Raptor KM870
# Error decoding JSON: Expecting ',' delimiter: line 14 column 27 (char 463). Skipping to next row.
# Skipping row 786 - Title: Keyboard Gaming Mechanical AULA S-2022 - Blue Switch - New Fashion LED
# Item 800 processed
# Error decoding JSON: Expecting ',' delimiter: line 17 column 30 (char 620). Skipping to next row.
# Skipping row 809 - Title: Press Play Voyager 68 V2 Lite RGB Hotswap Mechanical Gaming Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 413). Skipping to next row.
# Skipping row 814 - Title: Keyboard Gaming Mechanical Altec ALGK-8614 - Multimedia RGB Red Switch
# Item 850 processed
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 444). Skipping to next row.
# Skipping row 861 - Title: Keyboard Gaming Mechanical KOMIC KG-MK288 -New LED
# Item 900 processed
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 442). Skipping to next row.
# Skipping row 915 - Title: Keyboard Gaming Mechanical AULA S-2022 BLACK -New LED- Macro Software
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 456). Skipping to next row.
# Skipping row 917 - Title: Keyboard Gaming Mechanical AULA S2022 BLUE   RGB Display Rainbow   Macro Software   KRGD Blue Switch   Keycap and gap backlight   uniform color
# Error decoding JSON: Expecting ',' delimiter: line 15 column 46 (char 485). Skipping to next row.
# Skipping row 923 - Title: Keychron K6 Pro QMK/VIA Barebone Wireless Custom Mechanical Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 17 column 45 (char 677). Skipping to next row.
# Skipping row 929 - Title: BONUS POUCH + Keychron K3 WHITE Backlight GATERON Mechanical Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 17 column 30 (char 667). Skipping to next row.
# Skipping row 945 - Title: Cooler Master CK720 Grey RGB 65% Mechanical Gaming Keyboard - Kailh Box V2 Red Switch
# Item 950 processed
# Error decoding JSON: Expecting ',' delimiter: line 17 column 44 (char 684). Skipping to next row.
# Skipping row 959 - Title: Keychron K5 SE Hotswappable Gateron Mechanical White Wireless Keyboard
# Error decoding JSON: Expecting ',' delimiter: line 17 column 45 (char 595). Skipping to next row.
# Skipping row 998 - Title: Keychron K3 RGB Backlight Hot-swappable Low Profile Optical Switch Wireless Mechanical Keyboard
# Item 1000 processed
# Item 1050 processed
# Item 1100 processed
# Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping to next row.
# Skipping row 1121 - Title: Cooler Master CK720 Grey RGB 65% Mechanical Gaming Keyboard - Kailh Box V2 White Switch
# Item 1150 processed
# Error decoding JSON: Expecting value: line 18 column 23 (char 679). Skipping to next row.
# Skipping row 1157 - Title: Rexus Daiva D87 / D-87 Wireless Mechanical Keyboard Gaming TKL D 87
# Error decoding JSON: Expecting property name enclosed in double quotes: line 25 column 33 (char 852). Skipping to next row.
# Skipping row 1161 - Title: Fantech MK857 Maxfit61 Frost Wireless 60% Mechanical Gaming Keyboard
# Item 1200 processed
# Item 1250 processed
# Item 1300 processed
# Error decoding JSON: Expecting ',' delimiter: line 14 column 25 (char 443). Skipping to next row.
# Skipping row 1354 - Title: Keyboard Gaming Altec Lansing ALGK-8404 - RGB Blue Switch Ten Key Less Mechanical Keyboard - White & Grey Keycaps
# Item 1400 processed
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 493). Skipping to next row.
# Skipping row 1408 - Title: Keyboard Gaming Mechanical AULA S-2022 BLUERGB Display Rainbow - Macro Software
# Error decoding JSON: Expecting ',' delimiter: line 14 column 26 (char 462). Skipping to next row.
# Skipping row 1412 - Title: Keyboard Gaming Mechanical Aula S2022 26 Tombol Antighosting Pink
# Error decoding JSON: Expecting property name enclosed in double quotes: line 25 column 33 (char 800). Skipping to next row.
# Skipping row 1484 - Title: Fantech MK857 MAXFIT61 FROST Wireless Hotswap 60% Mechanical Gaming Keyboard White - Blue Switch
# Item 1500 processed
# Error decoding JSON: Expecting value: line 17 column 42 (char 579). Skipping to next row.
# Skipping row 1503 - Title: Keychron K10 Pro Barebone Hotswap Mechanical Gaming Keyboard
# Error decoding JSON: Expecting value: line 1 column 1 (char 0). Skipping to next row.
# Skipping row 1508 - Title: Keyboard Cooler Master MK730 Mechanical USB
# Item 1550 processed
# Item 1600 processed
# Item 1650 processed
# Item 1700 processed
# Error decoding JSON: Expecting ',' delimiter: line 25 column 34 (char 818). Skipping to next row.
# Skipping row 1715 - Title: Logitech G715 Keyboard Gaming Wireless Bluetooth Mechanical TKL RGB-Tactile
# Item 1750 processed
# Item 1800 processed
# Error decoding JSON: Expecting value: line 15 column 43 (char 465). Skipping to next row.
# Skipping row 1823 - Title: Keyboard Gaming Keyboard Mechanical Gamen Titan III Gamen Titan 3 RGB
# Item 1850 processed
# Error decoding JSON: Expecting property name enclosed in double quotes: line 25 column 33 (char 858). Skipping to next row.
# Skipping row 1859 - Title: Keyboard Gaming Fantech Mechanical MK857 MAXFIT61 FROST Wireless
# Error decoding JSON: Expecting property name enclosed in double quotes: line 25 column 33 (char 886). Skipping to next row.
# Skipping row 1883 - Title: Fantech MAXFIT61 FROST Wired Hotswap Keyboard Gaming Mechanical RGB
# Item 1900 processed
# Error decoding JSON: Expecting ',' delimiter: line 18 column 27 (char 617). Skipping to next row.
# Skipping row 1907 - Title: ASUS ROG Falchion Ace RGB 65% Wired Mechanical Gaming Keyboard
# Item 1950 processed
# Error decoding JSON: Expecting ',' delimiter: line 17 column 44 (char 777). Skipping to next row.
# Skipping row 1983 - Title: Cooler Master CK720 - CK-720 65% Mechanical Gaming Keyboard
# Item 2000 processed
# Error decoding JSON: Expecting ',' delimiter: line 17 column 44 (char 765). Skipping to next row.
# Skipping row 2031 - Title: Cooler Master CK720 - CK-720 65% Mechanical Gaming Keyboard
# Item 2050 processed
# Error decoding JSON: Expecting property name enclosed in double quotes: line 18 column 25 (char 594). Skipping to next row.
# Skipping row 2079 - Title: Keyboard Logitech G910 Orion Spectrum Keyboard Gaming RGb Mechanical
# Item 2100 processed
# Total 2128 rows processed

# %%
# Simpan dataframe ke file CSV baru
df.to_csv('mechanical-keyboard-processed.csv', index=False)

# %% [markdown]
# **Merging Duplicate Columns:** We identify and merge columns with duplicate information to streamline the dataset. This includes merging columns related to dimensions and weight.

# %%
# Kolom-kolom yang akan digabungkan
columns_to_merge = [
    ("Brand (Category)", "Brand"),
    ("Material casing (Category)", "Material casing"),
    ("Underglow RGB (Yes/No)", "Underglow RGB"),
    ("South-facing RGB switch (Yes/No)", "South-facing RGB switch"),
    ("Hot-swappable (5 pin) (Yes/No)", "Hot-swappable (5 pin)"),
    ("Compatibility with mechanical switch (Category)", "Compatibility with mechanical switch"),
    ("Magic FN key (Yes/No)", "Magic FN key"),
    ("Software customization (Yes/No)", "Software customization"),
    ("Keycap profile (Category)", "Keycap profile"),
    ("Color options (Category)", "Color options"),
    ("Switch options (Category)", "Switch options"),
    ("Keyboard layout (Category)", "Keyboard layout"),
    ("Number of keys (Number)", "Number of keys"),
    ("Dimensions (Length) (millimeters)", "Dimensions (Length)"),
    ("Dimensions (Width) (millimeters)", "Dimensions (Width)"),
    ("Dimensions (Height) (millimeters)", "Dimensions (Height)"),
    ("Weight (grams)", "Weight"),
    ("Pre-lubed stabilizer (Yes/No)", "Pre-lubed stabilizer"),
    ("Include damper foam (Yes/No)", "Include damper foam"),
    ("Detachable Type-C (Yes/No)", "Detachable Type-C"),
    ("Onboard memory (Yes/No)", "Onboard memory"),
    ("Anti-ghosting (Yes/No)", "Anti-ghosting"),
    ("RGB Per-Key (Yes/No)", "RGB Per-Key"),
    ("Battery capacity (mAh)", "Battery capacity")
]

# Melakukan merge kolom-kolom yang duplikat
for col1, col2 in columns_to_merge:
    df[col1].fillna(df[col2], inplace=True)
    df.drop(columns=[col2], inplace=True)

# %%
df
# Out:
#                                                   Title Reviews Sold
# 0     Keyboard Gaming Mechanical Rexus MX9 TKL Legio...     NaN  NaN  \
# 1     Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...     NaN  NaN
# 2     PXN K30 Gaming TKL Battledock Mechanical Keybo...     NaN  NaN
# 3     Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...     NaN  NaN
# 4     Gamen GMK01 PBT Keycaps - keycaps Mechanical k...     NaN  NaN
# ...                                                 ...     ...  ...
# 2123  BEST SELLER 1STPLAYER Mechanical Gaming Keyboa...     NaN  NaN
# 2124  PROMO Powerlogic Armageddon MKA 9C RGB Mechani...     NaN  NaN
# 2125  Terunik Powerlogic Armageddon MKA 5R RGB Mecha...     NaN  NaN
# 2126  Terunik Powerlogic Armageddon MKA 11R RGB Mech...     NaN  NaN
# 2127  BEST SELLER Cougar Mechanical Gaming Keyboard ...     NaN  NaN
#
#      Original Price             Store Name      Store City
# 0         Rp549.000             uneed shop   Jakarta Utara  \
# 1       Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2         Rp538.700          Store Pinokio  Kab. Tangerang
# 3         Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4          Rp79.000               Starcomp          Sleman
# ...             ...                    ...             ...
# 2123    Rp1.425.000                 Nelson   Jakarta Barat
# 2124    Rp1.185.000                 Nelson   Jakarta Barat
# 2125    Rp1.440.000                 Nelson   Jakarta Barat
# 2126    Rp1.612.500                 Nelson   Jakarta Barat
# 2127    Rp1.320.000                 Nelson   Jakarta Barat
#
#                                             Description Order Processing
# 0     Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1     Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2     Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3     POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4     Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
# ...                                                 ...              ...
# 2123  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 2124  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 2125  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 2126  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 2127  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
#
#            Positive Feedback       Total Feedback  ... Anti-ghosting (Yes/No)
# 0     6.516 Feedback Positif  dari 6.541 feedback  ...                    Yes  \
# 1     1.216 Feedback Positif  dari 1.275 feedback  ...                    Yes
# 2     3.132 Feedback Positif  dari 3.136 feedback  ...                    Yes
# 3     4.253 Feedback Positif  dari 4.479 feedback  ...                    Yes
# 4     5.693 Feedback Positif  dari 5.940 feedback  ...                      -
# ...                      ...                  ...  ...                    ...
# 2123      3 Feedback Positif      dari 6 feedback  ...                    Yes
# 2124      3 Feedback Positif      dari 6 feedback  ...                    Yes
# 2125      3 Feedback Positif      dari 6 feedback  ...                    Yes
# 2126      3 Feedback Positif      dari 6 feedback  ...                    Yes
# 2127      3 Feedback Positif      dari 6 feedback  ...                    Yes
#
#      RGB Per-Key (Yes/No) Battery capacity (mAh) Dimensions (Length) (mm)
# 0                      No                      -                      NaN  \
# 1                     Yes                   3750                      NaN
# 2                      No                   1850                      NaN
# 3                     Yes                      -                      NaN
# 4                       -                      -                      NaN
# ...                   ...                    ...                      ...
# 2123                   No                      -                      NaN
# 2124                   No                      -                      NaN
# 2125                   No                      -                      NaN
# 2126                   No                      -                      NaN
# 2127                  Yes                      -                      NaN
#
#      Dimensions (Width) (mm) Dimensions (Height) (mm) Weight (g)
# 0                        NaN                      NaN        NaN  \
# 1                        NaN                      NaN        NaN
# 2                        NaN                      NaN        NaN
# 3                        NaN                      NaN        NaN
# 4                        NaN                      NaN        NaN
# ...                      ...                      ...        ...
# 2123                     NaN                      NaN        NaN
# 2124                     NaN                      NaN        NaN
# 2125                     NaN                      NaN        NaN
# 2126                     NaN                      NaN        NaN
# 2127                     NaN                      NaN        NaN
#
#      Supported Systems Include dampener foam Dimensions (Height)(millimeters)
# 0                  NaN                   NaN                              NaN
# 1                  NaN                   NaN                              NaN
# 2                  NaN                   NaN                              NaN
# 3                  NaN                   NaN                              NaN
# 4                  NaN                   NaN                              NaN
# ...                ...                   ...                              ...
# 2123               NaN                   NaN                              NaN
# 2124               NaN                   NaN                              NaN
# 2125               NaN                   NaN                              NaN
# 2126               NaN                   NaN                              NaN
# 2127               NaN                   NaN                              NaN
#
# [1864 rows x 42 columns]

# %%
# Kolom-kolom yang akan digabungkan
columns_to_merge = [
    ("Dimensions (Length) (millimeters)", "Dimensions (Length) (mm)"),
    ("Dimensions (Width) (millimeters)", "Dimensions (Width) (mm)"),
    ("Dimensions (Height) (millimeters)", "Dimensions (Height) (mm)"),
    ("Weight (grams)", "Weight (g)"),
    ("Include damper foam (Yes/No)", "Include dampener foam")
]

# Melakukan merge kolom-kolom yang duplikat
for col1, col2 in columns_to_merge:
    df[col1].fillna(df[col2], inplace=True)
    df.drop(columns=[col2], inplace=True)

# %%
df.head()
# Out:
#                                                Title Reviews Sold
# 0  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...     NaN  NaN  \
# 1  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...     NaN  NaN
# 2  PXN K30 Gaming TKL Battledock Mechanical Keybo...     NaN  NaN
# 3  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...     NaN  NaN
# 4  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...     NaN  NaN
#
#   Original Price             Store Name      Store City
# 0      Rp549.000             uneed shop   Jakarta Utara  \
# 1    Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2      Rp538.700          Store Pinokio  Kab. Tangerang
# 3      Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4       Rp79.000               Starcomp          Sleman
#
#                                          Description Order Processing
# 0  Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1  Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2  Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3  POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4  Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
#
#         Positive Feedback       Total Feedback  ... Weight (grams)
# 0  6.516 Feedback Positif  dari 6.541 feedback  ...          950.0  \
# 1  1.216 Feedback Positif  dari 1.275 feedback  ...          800.0
# 2  3.132 Feedback Positif  dari 3.136 feedback  ...              -
# 3  4.253 Feedback Positif  dari 4.479 feedback  ...          566.0
# 4  5.693 Feedback Positif  dari 5.940 feedback  ...              -
#
#   Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0                            No                           No  \
# 1                            No                           No
# 2                            No                           No
# 3                           Yes                          Yes
# 4                             -                            -
#
#   Detachable Type-C (Yes/No) Onboard memory (Yes/No) Anti-ghosting (Yes/No)
# 0                         No                     Yes                    Yes  \
# 1                        Yes                      No                    Yes
# 2                        Yes                      No                    Yes
# 3                        Yes                     Yes                    Yes
# 4                          -                       -                      -
#
#   RGB Per-Key (Yes/No) Battery capacity (mAh) Supported Systems
# 0                   No                      -               NaN  \
# 1                  Yes                   3750               NaN
# 2                   No                   1850               NaN
# 3                  Yes                      -               NaN
# 4                    -                      -               NaN
#
#   Dimensions (Height)(millimeters)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 37 columns]

# %%
# Kolom-kolom yang akan digabungkan
columns_to_merge = [
    ("Dimensions (Height) (millimeters)", "Dimensions (Height)(millimeters)")
]

# Melakukan merge kolom-kolom yang duplikat
for col1, col2 in columns_to_merge:
    df[col1].fillna(df[col2], inplace=True)
    df.drop(columns=[col2], inplace=True)

# %%
# Menghapus kolom "Supported Systems"
df.drop(columns=["Supported Systems"], inplace=True)

# %%
# Simpan dataframe ke file CSV baru
df.to_csv('mechanical-keyboard-processed-merged.csv', index=False)

# %%
df = pd.read_csv("D:\Career\QWork\chatgpt\mechanical-keyboard-processed-merged.csv")

# %%
df.head()
# Out:
#                                                Title Reviews Sold
# 0  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...     NaN  NaN  \
# 1  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...     NaN  NaN
# 2  PXN K30 Gaming TKL Battledock Mechanical Keybo...     NaN  NaN
# 3  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...     NaN  NaN
# 4  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...     NaN  NaN
#
#   Original Price             Store Name      Store City
# 0      Rp549.000             uneed shop   Jakarta Utara  \
# 1    Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2      Rp538.700          Store Pinokio  Kab. Tangerang
# 3      Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4       Rp79.000               Starcomp          Sleman
#
#                                          Description Order Processing
# 0  Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1  Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2  Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3  POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4  Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
#
#         Positive Feedback       Total Feedback  ...
# 0  6.516 Feedback Positif  dari 6.541 feedback  ...  \
# 1  1.216 Feedback Positif  dari 1.275 feedback  ...
# 2  3.132 Feedback Positif  dari 3.136 feedback  ...
# 3  4.253 Feedback Positif  dari 4.479 feedback  ...
# 4  5.693 Feedback Positif  dari 5.940 feedback  ...
#
#   Dimensions (Width) (millimeters) Dimensions (Height) (millimeters)
# 0                            133.5                              22.5  \
# 1                            126.0                              41.5
# 2                            102.0                              40.0
# 3                            103.0                              42.0
# 4                                -                                 -
#
#   Weight (grams) Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0          950.0                            No                           No  \
# 1          800.0                            No                           No
# 2              -                            No                           No
# 3          566.0                           Yes                          Yes
# 4              -                             -                            -
#
#   Detachable Type-C (Yes/No) Onboard memory (Yes/No) Anti-ghosting (Yes/No)
# 0                         No                     Yes                    Yes  \
# 1                        Yes                      No                    Yes
# 2                        Yes                      No                    Yes
# 3                        Yes                     Yes                    Yes
# 4                          -                       -                      -
#
#   RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                   No                      -
# 1                  Yes                   3750
# 2                   No                   1850
# 3                  Yes                      -
# 4                    -                      -
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Step 2: Data Cleaning and Preparation

# %% [markdown]
# **Removing Rows with Missing Titles:** We remove rows with missing attributes as they are crucial for the description extraction process.

# %%
# Count the number of rows before removal
total_rows_before = df.shape[0]

# Remove rows with empty values in the 'Brand (Category)' column
df.dropna(subset=['Brand (Category)'], inplace=True)

# Count the number of rows after removal
total_rows_after = df.shape[0]

# Calculate the number of rows removed
rows_removed = total_rows_before - total_rows_after

print(f"Number of rows removed: {rows_removed}")
# Out:
# Number of rows removed: 43

# %% [markdown]
# **Cleaning Feedback Columns:** We clean the 'Positive Feedback' and 'Total Feedback' columns, removing unnecessary text and converting them to integer values.

# %%
import re

# Function to clean the feedback string
def clean_feedback(feedback):
    if isinstance(feedback, str):
        # Remove dots
        feedback = feedback.replace('.', '')
        # Remove " Feedback Positif"
        feedback = re.sub(r'\sFeedback\sPositif', '', feedback)
    return feedback

# %%
# Apply the function to the entire 'Positive Feedback' column
df['Positive Feedback'] = df['Positive Feedback'].apply(lambda x: clean_feedback(x))

# %%
df.head()
# Out:
#                                                Title Reviews Sold
# 0  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...     NaN  NaN  \
# 1  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...     NaN  NaN
# 2  PXN K30 Gaming TKL Battledock Mechanical Keybo...     NaN  NaN
# 3  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...     NaN  NaN
# 4  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...     NaN  NaN
#
#   Original Price             Store Name      Store City
# 0      Rp549.000             uneed shop   Jakarta Utara  \
# 1    Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2      Rp538.700          Store Pinokio  Kab. Tangerang
# 3      Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4       Rp79.000               Starcomp          Sleman
#
#                                          Description Order Processing
# 0  Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1  Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2  Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3  POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4  Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
#
#   Positive Feedback       Total Feedback  ...
# 0              6516  dari 6.541 feedback  ...  \
# 1              1216  dari 1.275 feedback  ...
# 2              3132  dari 3.136 feedback  ...
# 3              4253  dari 4.479 feedback  ...
# 4              5693  dari 5.940 feedback  ...
#
#   Dimensions (Width) (millimeters) Dimensions (Height) (millimeters)
# 0                            133.5                              22.5  \
# 1                            126.0                              41.5
# 2                            102.0                              40.0
# 3                            103.0                              42.0
# 4                                -                                 -
#
#   Weight (grams) Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0          950.0                            No                           No  \
# 1          800.0                            No                           No
# 2              -                            No                           No
# 3          566.0                           Yes                          Yes
# 4              -                             -                            -
#
#   Detachable Type-C (Yes/No) Onboard memory (Yes/No) Anti-ghosting (Yes/No)
# 0                         No                     Yes                    Yes  \
# 1                        Yes                      No                    Yes
# 2                        Yes                      No                    Yes
# 3                        Yes                     Yes                    Yes
# 4                          -                       -                      -
#
#   RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                   No                      -
# 1                  Yes                   3750
# 2                   No                   1850
# 3                  Yes                      -
# 4                    -                      -
#
# [5 rows x 35 columns]

# %%
# Function to clean the total feedback string
def clean_total_feedback(feedback):
    if isinstance(feedback, str):
        # Mencocokkan angka dalam string menggunakan ekspresi reguler
        numeric_part = re.search(r'[\d,\.]+', feedback)
        if numeric_part:
            numeric_value = int(numeric_part.group().replace(',', '').replace('.', ''))
            return numeric_value
    return None  # Mengembalikan None jika tidak ada angka yang ditemukan

# %%
# Apply the function to the entire 'Positive Feedback' column
df['Total Feedback'] = df['Total Feedback'].apply(lambda x: clean_total_feedback(x))

# %%
df.head()
# Out:
#                                                Title Reviews Sold
# 0  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...     NaN  NaN  \
# 1  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...     NaN  NaN
# 2  PXN K30 Gaming TKL Battledock Mechanical Keybo...     NaN  NaN
# 3  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...     NaN  NaN
# 4  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...     NaN  NaN
#
#   Original Price             Store Name      Store City
# 0      Rp549.000             uneed shop   Jakarta Utara  \
# 1    Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2      Rp538.700          Store Pinokio  Kab. Tangerang
# 3      Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4       Rp79.000               Starcomp          Sleman
#
#                                          Description Order Processing
# 0  Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1  Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2  Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3  POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4  Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
#
#   Positive Feedback  Total Feedback  ... Dimensions (Width) (millimeters)
# 0              6516          6541.0  ...                            133.5  \
# 1              1216          1275.0  ...                            126.0
# 2              3132          3136.0  ...                            102.0
# 3              4253          4479.0  ...                            103.0
# 4              5693          5940.0  ...                                -
#
#   Dimensions (Height) (millimeters) Weight (grams)
# 0                              22.5          950.0  \
# 1                              41.5          800.0
# 2                              40.0              -
# 3                              42.0          566.0
# 4                                 -              -
#
#   Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0                            No                           No  \
# 1                            No                           No
# 2                            No                           No
# 3                           Yes                          Yes
# 4                             -                            -
#
#   Detachable Type-C (Yes/No) Onboard memory (Yes/No) Anti-ghosting (Yes/No)
# 0                         No                     Yes                    Yes  \
# 1                        Yes                      No                    Yes
# 2                        Yes                      No                    Yes
# 3                        Yes                     Yes                    Yes
# 4                          -                       -                      -
#
#   RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                   No                      -
# 1                  Yes                   3750
# 2                   No                   1850
# 3                  Yes                      -
# 4                    -                      -
#
# [5 rows x 35 columns]

# %%
# Fill NaN values with 0 in 'Positive Feedback' and 'Total Feedback' columns
df['Positive Feedback'] = df['Positive Feedback'].fillna(0)
df['Total Feedback'] = df['Total Feedback'].fillna(0)

# Convert 'Positive Feedback' and 'Total Feedback' columns to integers
df['Positive Feedback'] = df['Positive Feedback'].astype(int)
df['Total Feedback'] = df['Total Feedback'].astype(int)

# %%
df.head()
# Out:
#                                                Title Reviews Sold
# 0  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...     NaN  NaN  \
# 1  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...     NaN  NaN
# 2  PXN K30 Gaming TKL Battledock Mechanical Keybo...     NaN  NaN
# 3  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...     NaN  NaN
# 4  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...     NaN  NaN
#
#   Original Price             Store Name      Store City
# 0      Rp549.000             uneed shop   Jakarta Utara  \
# 1    Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2      Rp538.700          Store Pinokio  Kab. Tangerang
# 3      Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4       Rp79.000               Starcomp          Sleman
#
#                                          Description Order Processing
# 0  Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1  Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2  Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3  POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4  Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
#
#    Positive Feedback  Total Feedback  ... Dimensions (Width) (millimeters)
# 0               6516            6541  ...                            133.5  \
# 1               1216            1275  ...                            126.0
# 2               3132            3136  ...                            102.0
# 3               4253            4479  ...                            103.0
# 4               5693            5940  ...                                -
#
#   Dimensions (Height) (millimeters) Weight (grams)
# 0                              22.5          950.0  \
# 1                              41.5          800.0
# 2                              40.0              -
# 3                              42.0          566.0
# 4                                 -              -
#
#   Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0                            No                           No  \
# 1                            No                           No
# 2                            No                           No
# 3                           Yes                          Yes
# 4                             -                            -
#
#   Detachable Type-C (Yes/No) Onboard memory (Yes/No) Anti-ghosting (Yes/No)
# 0                         No                     Yes                    Yes  \
# 1                        Yes                      No                    Yes
# 2                        Yes                      No                    Yes
# 3                        Yes                     Yes                    Yes
# 4                          -                       -                      -
#
#   RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                   No                      -
# 1                  Yes                   3750
# 2                   No                   1850
# 3                  Yes                      -
# 4                    -                      -
#
# [5 rows x 35 columns]

# %% [markdown]
# **Cleaning Numeric Columns:** We clean and convert various numeric columns like 'Original Price', 'Reviews', and 'Sold' to appropriate data types.

# %%
# Remove the substring " Ulasan" from non-empty values in 'Reviews' column
df['Reviews'] = df['Reviews'].str.replace(' Ulasan', '')

# %%
# Fill NaN values in 'Reviews' column with 0
df['Reviews'] = df['Reviews'].fillna(0)

# %%
# Convert 'Reviews' column to integer data type
df['Reviews'] = df['Reviews'].astype(int)

# %%
# Remove the substring " Terjual" from non-empty values in 'Sold' column
df['Sold'] = df['Sold'].str.replace(' Terjual', '')

# %%
# Fill NaN values in 'Sold' column with 0
df['Sold'] = df['Sold'].fillna(0)

# %%
df
# Out:
#                                                   Title  Reviews Sold
# 0     Keyboard Gaming Mechanical Rexus MX9 TKL Legio...        0    0  \
# 1     Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...        0    0
# 2     PXN K30 Gaming TKL Battledock Mechanical Keybo...        0    0
# 3     Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...        0    0
# 4     Gamen GMK01 PBT Keycaps - keycaps Mechanical k...        0    0
# ...                                                 ...      ...  ...
# 1859  BEST SELLER 1STPLAYER Mechanical Gaming Keyboa...        0    0
# 1860  PROMO Powerlogic Armageddon MKA 9C RGB Mechani...        0    0
# 1861  Terunik Powerlogic Armageddon MKA 5R RGB Mecha...        0    0
# 1862  Terunik Powerlogic Armageddon MKA 11R RGB Mech...        0    0
# 1863  BEST SELLER Cougar Mechanical Gaming Keyboard ...        0    0
#
#      Original Price             Store Name      Store City
# 0         Rp549.000             uneed shop   Jakarta Utara  \
# 1       Rp1.049.000          Gaming Distro   Jakarta Pusat
# 2         Rp538.700          Store Pinokio  Kab. Tangerang
# 3         Rp518.400  Distributor_Aksesoris   Jakarta Pusat
# 4          Rp79.000               Starcomp          Sleman
# ...             ...                    ...             ...
# 1859    Rp1.425.000                 Nelson   Jakarta Barat
# 1860    Rp1.185.000                 Nelson   Jakarta Barat
# 1861    Rp1.440.000                 Nelson   Jakarta Barat
# 1862    Rp1.612.500                 Nelson   Jakarta Barat
# 1863    Rp1.320.000                 Nelson   Jakarta Barat
#
#                                             Description Order Processing
# 0     Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1     Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2     Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3     POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4     Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
# ...                                                 ...              ...
# 1859  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1860  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1861  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1862  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1863  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
#
#       Positive Feedback  Total Feedback  ... Dimensions (Width) (millimeters)
# 0                  6516            6541  ...                            133.5  \
# 1                  1216            1275  ...                            126.0
# 2                  3132            3136  ...                            102.0
# 3                  4253            4479  ...                            103.0
# 4                  5693            5940  ...                                -
# ...                 ...             ...  ...                              ...
# 1859                  3               6  ...                              230
# 1860                  3               6  ...                                -
# 1861                  3               6  ...                              146
# 1862                  3               6  ...                                -
# 1863                  3               6  ...                              445
#
#      Dimensions (Height) (millimeters) Weight (grams)
# 0                                 22.5          950.0  \
# 1                                 41.5          800.0
# 2                                 40.0              -
# 3                                 42.0          566.0
# 4                                    -              -
# ...                                ...            ...
# 1859                                45           1400
# 1860                                 -              -
# 1861                                38              -
# 1862                                 -              -
# 1863                                40              -
#
#      Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0                               No                           No  \
# 1                               No                           No
# 2                               No                           No
# 3                              Yes                          Yes
# 4                                -                            -
# ...                            ...                          ...
# 1859                            No                           No
# 1860                            No                           No
# 1861                            No                           No
# 1862                            No                           No
# 1863                            No                           No
#
#      Detachable Type-C (Yes/No) Onboard memory (Yes/No)
# 0                            No                     Yes  \
# 1                           Yes                      No
# 2                           Yes                      No
# 3                           Yes                     Yes
# 4                             -                       -
# ...                         ...                     ...
# 1859                         No                      No
# 1860                         No                      No
# 1861                         No                      No
# 1862                         No                     Yes
# 1863                         No                      No
#
#      Anti-ghosting (Yes/No) RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                       Yes                   No                      -
# 1                       Yes                  Yes                   3750
# 2                       Yes                   No                   1850
# 3                       Yes                  Yes                      -
# 4                         -                    -                      -
# ...                     ...                  ...                    ...
# 1859                    Yes                   No                      -
# 1860                    Yes                   No                      -
# 1861                    Yes                   No                      -
# 1862                    Yes                   No                      -
# 1863                    Yes                  Yes                      -
#
# [1821 rows x 35 columns]

# %%
df.to_csv("test-3.csv", index=False)

# %%
df = pd.read_csv('test-3.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 35 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Title                                            1821 non-null   object
#  1   Reviews                                          1821 non-null   int64
#  2   Sold                                             1821 non-null   float64
#  3   Original Price                                   1821 non-null   object
#  4   Store Name                                       1821 non-null   object
#  5   Store City                                       1821 non-null   object
#  6   Description                                      1821 non-null   object
#  7   Order Processing                                 1802 non-null   object
#  8   Positive Feedback                                1821 non-null   int64
#  9   Total Feedback                                   1821 non-null   int64
#  10  Product URL                                      1821 non-null   object
#  11  Brand (Category)                                 1821 non-null   object
#  12  Material casing (Category)                       1821 non-null   object
#  13  Underglow RGB (Yes/No)                           1821 non-null   object
#  14  South-facing RGB switch (Yes/No)                 1821 non-null   object
#  15  Hot-swappable (5 pin) (Yes/No)                   1821 non-null   object
#  16  Compatibility with mechanical switch (Category)  1821 non-null   object
#  17  Magic FN key (Yes/No)                            1821 non-null   object
#  18  Software customization (Yes/No)                  1821 non-null   object
#  19  Keycap profile (Category)                        1820 non-null   object
#  20  Color options (Category)                         1818 non-null   object
#  21  Switch options (Category)                        1820 non-null   object
#  22  Keyboard layout (Category)                       1818 non-null   object
#  23  Number of keys (Number)                          1814 non-null   object
#  24  Dimensions (Length) (millimeters)                1812 non-null   object
#  25  Dimensions (Width) (millimeters)                 1812 non-null   object
#  26  Dimensions (Height) (millimeters)                1812 non-null   object
#  27  Weight (grams)                                   1812 non-null   object
#  28  Pre-lubed stabilizer (Yes/No)                    1821 non-null   object
#  29  Include damper foam (Yes/No)                     1821 non-null   object
#  30  Detachable Type-C (Yes/No)                       1821 non-null   object
#  31  Onboard memory (Yes/No)                          1821 non-null   object
#  32  Anti-ghosting (Yes/No)                           1821 non-null   object
#  33  RGB Per-Key (Yes/No)                             1821 non-null   object
#  34  Battery capacity (mAh)                           1817 non-null   object
# dtypes: float64(1), int64(3), object(31)
# memory usage: 498.1+ KB

# %%
# Remove non-numeric characters from 'Original Price' column and convert to integer
df['Original Price'] = df['Original Price'].str.replace('Rp', '').str.replace('.', '').astype(int)

# %% [markdown]
# **Standardizing Brand Names:** We standardize brand names using a predefined dictionary to ensure consistency.

# %%
unique_brands = df['Brand (Category)'].unique()
print(unique_brands)
# Out:
# ['Rexus (Gaming Mechanical Keyboard)' 'Rexus' 'PXN' 'Fantech' 'Gamen'
#  'Redragon' 'Leopold' 'Ducky' 'Tecware' 'Cooler Master (Gaming Keyboard)'
#  'AULA' 'POWERUP RAPTOR' 'Thermaltake' 'Keycaps Gundam Theme'
#  'Rexus (Gaming Keyboard)' 'Clover Garment Indonesia' 'Rexus Daxa'
#  'Logitech' 'Digital Alliance' 'Cooler Master' 'Keychron' 'Aukey' 'Daxa'
#  'Gateron' 'NYK' 'Gamen Titan IV' 'ZHUIGUANGBAO' 'Altec Lansing' 'Aula'
#  'Logitech G413' 'Rapoo' 'VODOOL' 'GAMEN' 'Armaggeddon' 'Sades' 'Cherry'
#  'Royal Kludge' 'ZIYOULANG' 'NB' 'Keycaps mechanical' 'HyperX' 'Imperion'
#  'WORKMATE II' 'Paradox Gaming' 'Noxelic' 'Leopard' 'MSI' 'Rexus MX5.2'
#  'Keycaps Gundam Theme Set' 'NOIR' 'SADES' 'Gamdias'
#  'Razer (Gaming Keyboard)' 'Rexus Daiva' 'Tombol' 'FOOMEE' 'Leopard G20'
#  'CYBORG' 'Logitech G413SE' 'Keycaps CLV' 'HAVIT' 'Kingston HyperX'
#  'TOMBOL' 'K68' 'COOLER MASTER' 'Raptor' 'COUGAR' 'LOGITECH'
#  'Redragon (Gaming Keyboard)' 'VD12' 'Paradox Gaming Ghost' 'DAREU' '-'
#  'Shortcut' 'Rexus MX9' 'Skyloong' 'Remax' 'Dareu'
#  'Originale Leopard G700' 'COUGAR (Gaming Keyboard)' 'ASUS TUF Gaming'
#  'Casing Rexus Keyboard' 'Razer' 'NYK Nemesis' 'Clover Gaming Indonesia'
#  'CHERRY' 'Predator' 'Noir YC8 Aviator' 'FANTECH'
#  'RAPOO VPRO V510 Mechanical Keyboard Gaming' 'DELUXE' 'Y-FRUITFUL'
#  'DragonWar' 'TECWARE' 'Tecware (Gaming Keyboard)' 'Noir' 'Komic' 'MARVO'
#  'HP' 'RAPOO VPRO' 'ALTEC' 'Leaven' 'MAXFIT67' 'NYK Nemesis Helens'
#  'FIREROSE Gaming' 'VD6R' 'HELENS MKN-06' 'Redragon (Gaming)' 'VD6B' 'PBT'
#  'Combo' 'Robot Workmate II' 'Rexus DAXA' 'GAMING DA' '5STAR' 'Vivan'
#  'LEORQEON' 'Outemu' 'GATERON' 'GENSHIN IMPACT' 'Keycaps' 'Havit' 'Cyborg'
#  'Noir Timeless'
#  'Gaming Keyboard RGB Backlight Mechanical Feel Waterproof - N35'
#  'Redragon SCARAB A130 Keycaps' 'Philips SPK8614 Momentum' '8Bitdo'
#  'Combo Gaming Keyboard' 'REDRAGON' 'Rexus Heroic' 'ROBOT' 'GAMING DISTRO'
#  'KOMIC' 'Cherry MX' 'HELENS' 'Warwolf' 'MIIIW' 'Hexgears' 'Xiaomi'
#  'Rexus Coiled Cable' 'REDRAGON (Gaming Keyboard)' 'Rexus Keyboard'
#  'ALLOYSEED' 'Titan Elite' 'ASUS ROG' 'ASUS (Gaming Keyboard)'
#  'SteelSeries (Gaming Keyboard)' 'E-YOOSO' 'Press Play' 'Akko' 'Altec'
#  'Gateron Switch - China Joy CJ' 'Aflion' 'Fantech (Gaming Keyboard)'
#  'CIY' 'CLOVER GAMING INDONESIA' 'YINDIAO' 'GT100' 'Pulsar'
#  'Rexus FR4 Plate' 'Ajazz' 'Jete' 'DAXA' 'Logitech G' 'Koodo' 'Monsgeek'
#  'G21B' 'FiiO KB1 KB1K' 'Logitech (Gaming)' 'Custom Service' 'Zuoya'
#  'ONIKUMA' 'Outemu Switch Mechanical Keyboard' 'Noir x Yunzii' 'NuPhy'
#  'Cidoo' 'FL Esports' 'Durock' 'MSI (Gaming Keyboard)' 'Gantungan Kunci'
#  'Otemu' 'Monsgeek x MYNK M7W' 'AULA (Gaming Keyboard)' 'Rover84' 'Vortex'
#  'Lecoo' 'Rexus Keyboard Gaming Mechanical Daxa M61 Barebone'
#  'Press Play Voyager' 'Vortex Series' 'TITAN II' 'Vortex Series GT9'
#  'MagiDeal' 'Chemicy Gaming' 'Digital Alliance Meca 8S'
#  'Rexus (Gaming Accessories)' 'Lenovo (Gaming Mechanical)' 'SERUNI'
#  'Keyboard Gaming Imperion' 'Noir Timeless82' 'Sikat' 'Mechanic' 'OUTEMU'
#  'Digital Alliance DA' 'INTNIUB' 'Logitech G413 SE' 'Rexus Ayaka Combo'
#  'Corsair' '3C-Tech' 'HyperX (Gaming Keyboard)' 'SteelSeries'
#  'Rexus KX-5 Heroic Series'
#  'Rexus KX-5 Heroic Series RGB Gaming Mechanical Keyboard Fullsize'
#  'BUZPER' 'Divipard' 'Keyboard Mechanical Bluetooth Wireless' 'CherryMX'
#  'HyperX Alloy FPS' 'Paradox' 'Keycap puller' 'Keycap Puller' 'Triple Key'
#  'E-YOOSO (Keyboard)' 'LEEDOAR' 'Logitech (Gaming Keyboard)' 'VODIRK'
#  'Logitech (Gaming Mechanical Keyboard)' 'Corsair (Gaming Keyboard)'
#  'Steelseries' 'ASUS' 'FOREV' 'Ducky x Dimanche' 'Switch Gateron' 'Titan'
#  'GAMEN Keyboard' 'Custom Decal Sticker' 'Patriot' 'TECSEE' 'Kailh Switch'
#  'Macro' 'Nuphy' 'Iqunix' 'Asus ROG' 'KBDFANS' 'NEXTTIME' 'SIKAKEYB'
#  'AZIO' 'TM680' 'AXE | MECHANICALS' 'SKYLOONG' 'Access IS' 'Alps'
#  'GIGABYTE AORUS' 'LDKAI' '1STPLAYER' 'Steelseries (Gaming)' 'Cougar'
#  'SADES KATANA' 'Bloody' 'Geek Customized' 'Access' 'Custom' 'SHIPADOO'
#  'Angry Miao' 'Pro Solder' 'REXUS' 'Maverick Microsystems' 'Limeide'
#  'ARMAGGEDDON' 'Sades Kunaii' 'Asus (Gaming Keyboard)' 'AJAZZ (Keyboard)'
#  'E-BLUE' 'AULA (Gaming)' 'AULA (Gaming Mechanical)' 'NEXT TIME' 'AXE'
#  'PAYSON' 'Azio (Gaming/Typing)' 'Azio' 'Aula S2022' 'Mini'
#  'Cooler Master MasterKeys' 'Romer-G' 'Lonson' 'Shipadoo'
#  'Cleaning Kit 5 in 1' 'AOC' 'AKKO' 'FEKER' 'Acer' 'Sades Rebellion'
#  'Marvo' 'Macropad' 'MSI (Gaming)' 'Ducky (Gaming/Typing)' 'Jual'
#  'TTesport' 'VortexSeries' 'JASA REPAIR' 'Flangeless' 'Robot' 'PHILIPS'
#  'Leaven Keyboard' 'Asus ROG Strix' 'ROBOT WORKMATE II' 'Joyko'
#  'Cooler Master (Gaming Mechanical Keyboard)'
#  'Fantech (Gaming Mechanical Keyboard)' 'DUROCK'
#  'Logitech G413 Carbon Mechanical Backlit Gaming Keyboard'
#  'HyperX Alloy Origins' 'BEESCLOVER' 'Asus' 'CORSAIR' 'Retro'
#  'HyperX Alloy Origins Core TKL' 'Aukey (Keyboard)' 'Logitech MX'
#  'Logitech G413 TKL SE Keyboard Gaming' 'LOFREE' 'Dumpad' 'Ducky One 3'
#  'Generic' 'Logitech G810 Orion Spectrum' 'Altech USA' 'Unknown (Vintage)'
#  'Signo Karenus & Kingangjia' 'GT8 Vortex Series' 'Kelowna' 'Vortek'
#  'Filco' 'Meetion' 'Azio (Retro Classic)' 'IMPERION'
#  'ASUS ROG Strix Scope RX EVA Edition' 'Vintage DK-9004A' 'Trigem'
#  'DMC Focus' 'Royal Kludge (RK)' 'Wired' 'ALTEC LANSING' 'Robot Workmate'
#  'RedDragon' 'Noir Z1' 'Titan IV' 'Armageddon' 'Apple' 'KPT' 'Dai-ichi'
#  'Sades Katana' 'Zifriend' 'Tecware Phantom' 'ROBOCOP FC' 'Keysporon'
#  'Powerlogic Armageddon']

# %%
len(unique_brands)
# Out:
# 356

# %%
import re

# Dictionary untuk mapping merek
brand_replacements = {
    'Rexus': 'Rexus',
    'Logitech': 'Logitech',
    'Tecware': 'Tecware',
    'NYK': 'NYK',
    'SteelSeries': 'SteelSeries',
    'MSI': 'MSI',
    'AULA': 'AULA',
    'Lenovo': 'Lenovo',
    'HyperX': 'HyperX',
    'E-YOOSO': 'E-YOOSO',
    'AJAZZ': 'AJAZZ',
    'Ducky': 'Ducky',
    'Cooler Master': 'Cooler Master',
    'Fantech': 'Fantech',
    'ASUS': 'ASUS',
    'Azio': 'Azio',
    'REDRAGON': 'REDRAGON',
    'Razer': 'Razer',
    'Rapoo': 'Rapoo',
    'Vintage': 'Vintage',
    'Royal Kludge': 'Royal Kludge',
    'Vortex': 'Vortex',
    'Keycap Puller': 'Keycap Puller',
    'COUGAR': 'COUGAR',
    'Powerlogic': 'Powerlogic',
    'AXE': 'AXE',
    'FiiO': 'FiiO',
    'Philips': 'Philips',
    'Noir': 'Noir'
}

# Fungsi untuk mengganti merek
def replace_brand(brand):
    for key, value in brand_replacements.items():
        if re.search(rf'\b{re.escape(key)}\b', brand, re.IGNORECASE):
            return value
    return brand

# Mengganti merek menggunakan fungsi replace_brand
df['Brand (Category)'] = df['Brand (Category)'].apply(replace_brand)

# %%
unique_brands = df['Brand (Category)'].unique()
print(unique_brands)
# Out:
# ['Rexus' 'PXN' 'Fantech' 'Gamen' 'REDRAGON' 'Leopold' 'Ducky' 'Tecware'
#  'Cooler Master' 'AULA' 'POWERUP RAPTOR' 'Thermaltake'
#  'Keycaps Gundam Theme' 'Clover Garment Indonesia' 'Logitech'
#  'Digital Alliance' 'Keychron' 'Aukey' 'Daxa' 'Gateron' 'NYK'
#  'Gamen Titan IV' 'ZHUIGUANGBAO' 'Altec Lansing' 'Rapoo' 'VODOOL' 'GAMEN'
#  'Armaggeddon' 'Sades' 'Cherry' 'Royal Kludge' 'ZIYOULANG' 'NB'
#  'Keycaps mechanical' 'HyperX' 'Imperion' 'WORKMATE II' 'Paradox Gaming'
#  'Noxelic' 'Leopard' 'MSI' 'Keycaps Gundam Theme Set' 'Noir' 'SADES'
#  'Gamdias' 'Razer' 'Tombol' 'FOOMEE' 'Leopard G20' 'CYBORG' 'Keycaps CLV'
#  'HAVIT' 'TOMBOL' 'K68' 'Raptor' 'COUGAR' 'VD12' 'Paradox Gaming Ghost'
#  'DAREU' '-' 'Shortcut' 'Skyloong' 'Remax' 'Dareu'
#  'Originale Leopard G700' 'ASUS' 'Clover Gaming Indonesia' 'CHERRY'
#  'Predator' 'DELUXE' 'Y-FRUITFUL' 'DragonWar' 'Komic' 'MARVO' 'HP' 'ALTEC'
#  'Leaven' 'MAXFIT67' 'FIREROSE Gaming' 'VD6R' 'HELENS MKN-06' 'VD6B' 'PBT'
#  'Combo' 'Robot Workmate II' 'GAMING DA' '5STAR' 'Vivan' 'LEORQEON'
#  'Outemu' 'GATERON' 'GENSHIN IMPACT' 'Keycaps' 'Havit' 'Cyborg'
#  'Gaming Keyboard RGB Backlight Mechanical Feel Waterproof - N35'
#  'Philips' '8Bitdo' 'Combo Gaming Keyboard' 'ROBOT' 'GAMING DISTRO'
#  'KOMIC' 'Cherry MX' 'HELENS' 'Warwolf' 'MIIIW' 'Hexgears' 'Xiaomi'
#  'ALLOYSEED' 'Titan Elite' 'SteelSeries' 'E-YOOSO' 'Press Play' 'Akko'
#  'Altec' 'Gateron Switch - China Joy CJ' 'Aflion' 'CIY'
#  'CLOVER GAMING INDONESIA' 'YINDIAO' 'GT100' 'Pulsar' 'AJAZZ' 'Jete'
#  'DAXA' 'Koodo' 'Monsgeek' 'G21B' 'FiiO' 'Custom Service' 'Zuoya'
#  'ONIKUMA' 'Outemu Switch Mechanical Keyboard' 'NuPhy' 'Cidoo'
#  'FL Esports' 'Durock' 'Gantungan Kunci' 'Otemu' 'Monsgeek x MYNK M7W'
#  'Rover84' 'Vortex' 'Lecoo' 'Press Play Voyager' 'TITAN II' 'MagiDeal'
#  'Chemicy Gaming' 'Digital Alliance Meca 8S' 'Lenovo' 'SERUNI'
#  'Keyboard Gaming Imperion' 'Sikat' 'Mechanic' 'OUTEMU'
#  'Digital Alliance DA' 'INTNIUB' 'Corsair' '3C-Tech' 'BUZPER' 'Divipard'
#  'Keyboard Mechanical Bluetooth Wireless' 'CherryMX' 'Paradox'
#  'Keycap Puller' 'Triple Key' 'LEEDOAR' 'VODIRK'
#  'Corsair (Gaming Keyboard)' 'FOREV' 'Switch Gateron' 'Titan'
#  'GAMEN Keyboard' 'Custom Decal Sticker' 'Patriot' 'TECSEE' 'Kailh Switch'
#  'Macro' 'Nuphy' 'Iqunix' 'KBDFANS' 'NEXTTIME' 'SIKAKEYB' 'Azio' 'TM680'
#  'AXE' 'SKYLOONG' 'Access IS' 'Alps' 'GIGABYTE AORUS' 'LDKAI' '1STPLAYER'
#  'SADES KATANA' 'Bloody' 'Geek Customized' 'Access' 'Custom' 'SHIPADOO'
#  'Angry Miao' 'Pro Solder' 'Maverick Microsystems' 'Limeide' 'ARMAGGEDDON'
#  'Sades Kunaii' 'E-BLUE' 'NEXT TIME' 'PAYSON' 'Mini' 'Romer-G' 'Lonson'
#  'Shipadoo' 'Cleaning Kit 5 in 1' 'AOC' 'AKKO' 'FEKER' 'Acer'
#  'Sades Rebellion' 'Marvo' 'Macropad' 'Jual' 'TTesport' 'VortexSeries'
#  'JASA REPAIR' 'Flangeless' 'Robot' 'Leaven Keyboard' 'ROBOT WORKMATE II'
#  'Joyko' 'DUROCK' 'BEESCLOVER' 'CORSAIR' 'Retro' 'Aukey (Keyboard)'
#  'LOFREE' 'Dumpad' 'Generic' 'Altech USA' 'Vintage'
#  'Signo Karenus & Kingangjia' 'Kelowna' 'Vortek' 'Filco' 'Meetion'
#  'IMPERION' 'Trigem' 'DMC Focus' 'Wired' 'ALTEC LANSING' 'Robot Workmate'
#  'RedDragon' 'Titan IV' 'Armageddon' 'Apple' 'KPT' 'Dai-ichi'
#  'Sades Katana' 'Zifriend' 'ROBOCOP FC' 'Keysporon' 'Powerlogic']

# %%
len(unique_brands)
# Out:
# 259

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 35 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Title                                            1821 non-null   object
#  1   Reviews                                          1821 non-null   int64
#  2   Sold                                             1821 non-null   float64
#  3   Original Price                                   1821 non-null   int32
#  4   Store Name                                       1821 non-null   object
#  5   Store City                                       1821 non-null   object
#  6   Description                                      1821 non-null   object
#  7   Order Processing                                 1802 non-null   object
#  8   Positive Feedback                                1821 non-null   int64
#  9   Total Feedback                                   1821 non-null   int64
#  10  Product URL                                      1821 non-null   object
#  11  Brand (Category)                                 1821 non-null   object
#  12  Material casing (Category)                       1821 non-null   object
#  13  Underglow RGB (Yes/No)                           1821 non-null   object
#  14  South-facing RGB switch (Yes/No)                 1821 non-null   object
#  15  Hot-swappable (5 pin) (Yes/No)                   1821 non-null   object
#  16  Compatibility with mechanical switch (Category)  1821 non-null   object
#  17  Magic FN key (Yes/No)                            1821 non-null   object
#  18  Software customization (Yes/No)                  1821 non-null   object
#  19  Keycap profile (Category)                        1820 non-null   object
#  20  Color options (Category)                         1818 non-null   object
#  21  Switch options (Category)                        1820 non-null   object
#  22  Keyboard layout (Category)                       1818 non-null   object
#  23  Number of keys (Number)                          1814 non-null   object
#  24  Dimensions (Length) (millimeters)                1812 non-null   object
#  25  Dimensions (Width) (millimeters)                 1812 non-null   object
#  26  Dimensions (Height) (millimeters)                1812 non-null   object
#  27  Weight (grams)                                   1812 non-null   object
#  28  Pre-lubed stabilizer (Yes/No)                    1821 non-null   object
#  29  Include damper foam (Yes/No)                     1821 non-null   object
#  30  Detachable Type-C (Yes/No)                       1821 non-null   object
#  31  Onboard memory (Yes/No)                          1821 non-null   object
#  32  Anti-ghosting (Yes/No)                           1821 non-null   object
#  33  RGB Per-Key (Yes/No)                             1821 non-null   object
#  34  Battery capacity (mAh)                           1817 non-null   object
# dtypes: float64(1), int32(1), int64(3), object(30)
# memory usage: 490.9+ KB

# %%
unique_materials = df['Material casing (Category)'].unique()
print(unique_materials)
# Out:
# ['Plastik ABS' 'ABS' 'Plastic' 'Polycarbonate' '-'
#  'Plastic body / Gunmetal Alloy Backplate' 'Plastic ABS'
#  'Plastic, Aluminum' 'Metal' 'PBT' 'High Quality ABS'
#  'Strong, corrosion-resistant material with smooth texture'
#  'Aluminum, Plastic' 'Metal Cover ABS' 'Aluminum, ABS' 'Mechanical'
#  'ABS Plastic' 'Sandblasted Aluminum, Plastic' 'Aluminum' 'Aluminum alloy'
#  'Acrylic and Plastic' 'FR4 Plate' 'PET mesh and braided cable'
#  'ABS Double Injection' 'Kevlar'
#  'Black Plastic Body / Gunmetal Alloy Backplate' 'ABS PA-758'
#  'PBT double injection' 'Aluminium plate'
#  'Strong, corrosion-resistant material'
#  'Resin, CNC Aluminium, CNC Acrylic' 'Top Cover Metal, Bottom Cover ABS'
#  'Silicon and Polycarbonate' 'PBT Dye Sub' 'Brushed Aluminum'
#  'Metal (Top Cover), ABS (Bottom Cover)'
#  'Plastic ABS with aluminum alloy cover' 'Metal Plate' 'ABS + Metal Cover'
#  'Transparent' 'Aluminum Alloy' 'Full aircraft-grade aluminum body'
#  'Carbon' 'Plastic, Aluminum, PU Leather' 'Metal and ABS' 'Acrylic'
#  'Gunmetal Black Color' 'Plastic ABS with metal protective cover'
#  'Black Transparent ABS' 'Premium materials' 'Aluminum-alloy' 'Metallic'
#  'Metal top plate' 'Plastic Body / Gunmetal Alloy Backplate'
#  'Gunmetal Black' 'ABS Aluminum alloy' 'Aluminum Frame'
#  'Top Cover - Metal, Bottom Cover - ABS' 'Steel and Plastic'
#  'Aluminium Alloy' 'Aluminium alloy aircraft-grade' 'Metal panel'
#  'PBT (Polybutylene Terephthalate)' 'Transparan Alphabet Keycaps'
#  'Plastic and Gunmetal Alloy' 'TPU (Thermoplastic Polyurethane)'
#  '5052 aluminum-magnesium alloy' 'TPU + woven mesh' 'Nylon, Metal, PVC'
#  'Plastic, Nature Rubber, Silicone' 'Aluminium' 'Aluminium and ABS'
#  'Aircraft-grade Aluminum' 'Aluminum top case' '5052 aluminum alloy'
#  'ABS Plated' 'Metal or Iron' 'Full metal material' 'Metal brushed plate'
#  'ABS construction' 'Silicone, POM, Aluminum, FR4' 'Metal body'
#  'ABS plastic' 'Top Cover :ABS, Bottom Cover :ABS' 'Metal base'
#  'ABS material' 'Aluminum alloy + ABS' 'Aluminum alloy shell'
#  'Woven Net, Metal' 'PBT Keycaps' 'Vinyl'
#  'Aircraft Grade Aluminum Alloy Frame' 'PBT Dye Sub Keycap'
#  'Original design PBT' 'Polycarbonate (PC) / Polyamide (PA)'
#  'Polycarbonate top shell/Nylon bottom shell/POM rod' 'PC' 'Rubber'
#  'High Quality Aluminum Panel' 'Nylon, POM, INK Blend' 'Minimalist design'
#  'Iron Plate' 'High quality polypropylene with brush metal finish'
#  'TPU (thermoplastic polyurethane) + braided mesh'
#  'High-Gloss Polycarbonate' 'Plastic ABS with metal cover'
#  'ABS with Metal Plate' 'Aluminum CNC' 'ABS/ABS+Aluminum'
#  'Magnesium-aluminum alloy (KB1), ABS + PMMA Plastic (KB1K)'
#  'ABS / ABS+Aluminum frame' 'Metal and quality plastic' 'Transparent case'
#  'Plastic-ABS' 'Aluminum, Polycarbonate' 'Powder coating CNC process case'
#  'Top Case + Middle Plate + PCBA'
#  'Stainless steel wire alloy, Nylon PA outer Casing'
#  'Full CNC machined aluminum' 'PLA 3D Printing'
#  'Aluminium Top Case, Gradient PBT Keycaps'
#  'Polycarbonate (PC), Polyamide (PA)' 'Plastic ABS, Metal Panel'
#  'Aluminum & Plastic' 'Aluminum (top), ABS+Aluminum (bottom)'
#  'Aluminum top case + plastic bottom case'
#  'Aluminum Top Case, Plastic Bottom Case' 'PBT Double Shot'
#  'Polycarbonate, FR4' '5052 Aluminum Alloy Top Case'
#  'Clear Case Transparent' 'TPU' 'CNC machined aluminum'
#  'ABS+Aluminum Frame' 'Triple Color with Double Injection'
#  'Aircraft-grade Aluminium' 'Aircraft-grade aluminum' 'Stainless Steel'
#  'Solid Body Build' 'White plastic' 'Clover Garment Indonesia'
#  'Metal Alloy' 'Silicone Rubber' 'ABS + Metal Top Plate Cover'
#  'Metal Panel' 'Aluminum frame' 'Solid Steel Frame'
#  'Aircraft-grade aluminum alloy' 'Zinc Alloy (Top), Plastic (Bottom)'
#  'Aircraft-Grade Aluminum' 'Aluminum Alloy Top Case' 'Metal top cover'
#  'Aluminum matte top plate' 'Solid steel frame' 'Silicon, Polycarbonate'
#  'Alloy' 'Gun-metal grey' 'Aircraft Grade Aluminum Alloy'
#  'Aircraft-Grade Aluminum Alloy' 'Injection molded plastic'
#  'Aircraft grade aluminum' 'Hardcase'
#  'Alu frame, Bottom Case ABS, Keycap PBT Double Shot'
#  'Aluminium Alloy Aircraft-Grade' 'Plastic and Metal'
#  'Top and Bottom ABS plastic case' 'Poron' 'Solid Construction'
#  'Matte Coating Material'
#  'Aluminium alloy with nickel scratch effect coating' 'Steel'
#  'Top graded ABS and metal'
#  'Reinforced ABS plastic and anodized aluminum plate' 'Metallic Cover'
#  'Transparent Plastic' 'Precision-locked covers with gaskets'
#  'Metal / ABS construction' 'Metal/ABS' 'Metallic body' 'PBT + ABS'
#  'Tank-solid material' 'Aluminium alloy' 'Costume handmade'
#  'Aluminum alloy plate' 'ABS Double Injection Keycaps' 'Plastic PBT'
#  'ALUMINIUM' 'Metal - Aluminum' 'Metal - Aluminium' 'KevlarTech'
#  'Aluminum (frame), ABS (bottom case)' 'Plastic with metal plate'
#  'Aluminium/Plastic' 'Fabric' 'Poly Carbonate'
#  'Leather/Wood/Aluminum Alloy' 'Leather and Aluminum alloy'
#  'Leather, Aluminum alloy' 'Transculent'
#  'PBT Double-Shot Keycaps (Keycaps)' 'High-quality aluminum alloy and ABS'
#  'Alumunium Alloy' 'AIRCRAFT-GRADE ALUMINUM' 'Acrylic + CNC'
#  'Aluminum, Leather' 'Aluminum alloy and ABS'
#  'Genuine leather or wood top plate'
#  'Aluminium alloy, Genuine leather or wood top plate' 'Leather'
#  'Aluminium Alloy Plate' 'Aluminum USB Housing' '5052 Aluminum Alloy'
#  'LED' 'Aluminium + ABS' 'ABS/PBT' 'ABS + Metal' 'Alloy top cover'
#  'Anodic Oxidation Aluminum' 'Silver' 'Sandblasted Aluminum / Plastic'
#  'Wood' 'Durable and long-lasting ROG PBT doubleshot keycaps'
#  'Full aircraft-grade aluminum' 'Acrylic/Aluminium/Resin'
#  'TPU (thermoplastic polyurethane) + knitted mesh'
#  'Doubleshot ABS Keycaps' 'Genuine Leather or Wood'
#  "{'Frame': 'Aluminum', 'Bottom case': 'ABS', 'Keycap': 'Double-shot PBT'}"
#  'Walnut Wood, Aluminum Zinc Alloy' 'Taiwan' 'Glacier Metal Case'
#  'Aluminum Frame, ABS Bottom Case, PBT Double Shot Keycap'
#  'Metal, Plastic' 'Aluminum Top Plate' 'Full aluminum body'
#  'Plastic Plate, Steel' 'Black case'
#  'Brushed metal top plate and matte coating keycaps'
#  'Durable Brushed Aluminum'
#  'Strong, corrosion-resistant material with smooth textured finish'
#  'Stainless Steel & Metal'
#  'Clear Polycarbonate and Clear Black Polycarbonate'
#  'Metal top cover case' 'Self-Developed' 'White and Brown' 'Not specified'
#  'Plastic with Metal Plate' 'Genuine leather or walnut wood top plate'
#  'Brushed Aluminum Alloy Panel' 'Piano / Plate Mount'
#  'Zinc-alloy frame with genuine leather surface'
#  'Aluminium alloy and leather/wood' 'PBT Plastic'
#  'Aluminum and Polycarbonate' 'Aluminum frame, ABS'
#  'High-quality ABS with top brush finish'
#  'Aluminium alloy and leather or wood top plate' 'ABS Frame'
#  'Strong and corrosion-resistant material'
#  'Harder and more durable than ABS plastic'
#  'Metal and TPU (Thermoplastic Polyurethane)' 'Plastic with Steel Plate'
#  'Anodized CNC Aluminum' 'Aluminum and ABS' '6061 aluminum alloy'
#  'ABS+Aluminum frame' 'Aluminum alloy and leather' 'Plastic (ABS) / PBT'
#  'Aluminium panel']

# %%
len(unique_materials)
# Out:
# 269

# %%
unique_underglow = df['Underglow RGB (Yes/No)'].unique()
print(unique_underglow)
# Out:
# ['No' 'Yes' '-']

# %%
unique_south_facing = df['South-facing RGB switch (Yes/No)'].unique()
print(unique_south_facing)
# Out:
# ['No' 'Yes' '-']

# %%
unique_hot_swap = df['Hot-swappable (5 pin) (Yes/No)'].unique()
print(unique_hot_swap)
# Out:
# ['No' 'Yes' '-']

# %%
unique_compatibility_mech_swith = df['Compatibility with mechanical switch (Category)'].unique()
print(unique_compatibility_mech_swith)
# Out:
# ['-' 'Gateron' 'Cherry MX'
#  'Gateron, Cherry, Kailh, and other 5-pin mechanical switch types' 'MX'
#  'Blue switch' 'Cherry MX Brown' 'Wraith Switches' 'Yes'
#  'Outemu Brown Switch' 'Cherry MX RGB Blue'
#  'Cherry MX, Outemu, Gateron, etc' 'Red Switch' 'SNK Switch' 'Fantech'
#  'Gateron KS-9' 'Romer-G Mechanical Switches' 'Outemu Removable Switch'
#  'Outemu Blue Switch' 'Low Profile Mechanical Switches'
#  'Gateron, Cherry, Kailh etc.' 'Outemu Switch' 'Outemu Red'
#  'TTC Low Profile Mechanical Switch (Red/Blue/Brown)'
#  'Cherry MX Blue and Cherry MX Red' 'Swappable switch' 'Blue Switch'
#  'Gateron Pro Milky Yellow / Red, JWK T1 (Blue)' 'Cherry MX Silent Red'
#  'Outemu' 'SNK Switch (Blue, Red, Brown)' 'Red/Blue/Brown'
#  'Tactile Mechanical Switch' 'Swappable 3 pin switch / 5 Pin Switch'
#  'Gateron, Cherry, Kailh' 'Outemu Removable Blue Switch' 'Universal'
#  'Romer-G' 'Romer-G Tactile/Linear, GX Blue' 'Red switch'
#  'Outemu Box Switch' 'Outemu Switches' 'Kailh' 'KTT White, KTT Ash Grey'
#  'Fantech Switch' 'Blue Switch & Red Switch' 'Cherry Profile 2-Tone PBT'
#  'Outemu Box Blue Switch' 'Not specified'
#  'Gateron Optical Blue, Red, Brown, Black, Yellow, Silver'
#  'Gateron Optical Blue,Red, Brown, Black, Yellow, Silver' 'Kailh, Jwick'
#  'Cherry MX, Gateron, Outemu, Kailh, and others' 'TTC Mechanical Switches'
#  'No' 'Cherry MX, Gateron, etc.' 'MX style switches'
#  'Low Profile Mechanical Switch' 'Outemu Removeable Blue Switch'
#  'Gamdias Certified Mechanical Switches' 'Razer Mechanical Switches'
#  'Kailh Socket' 'Mechanical blue switch' 'Outemu Removable Switch 3 pin'
#  'MX5 Legionare Mechanical Switch' '3-pin socket'
#  'OUTEMU Blue, Red, Brown Switch' 'Tactile' 'Cherry Profile'
#  'Cherry MX / Kailh / Gateron / Razer / Outemu / other mechanical switch'
#  'Blue Switch / Brown Switch' 'Kailh Red' 'HyperX Red, HyperX Aqua'
#  'Cherry MX, Gateron, Outemu, Kailh'
#  'Outemu Blue Switch, Outemu Red Switch'
#  'Outemu Switch (Blue Switch, Red Switch)'
#  'Cherry MX, Outemu, Gateron, etc (+ shape)'
#  'TTC Mechanical Switch (Red/Blue/Brown)' 'Outemu Red Switch'
#  'Romer-G Tactile' 'Cherry MX Red'
#  'Blue Switch, Red Switch & Brown Switch Available'
#  'Blue Switch, Brown Switch, Red Switch' 'MX-style switches'
#  'MX Switches (Blue, Red)' 'Cherry MX, Gateron, Kailh' 'OTUM Blue Switch'
#  'Gateron Gren Switch' 'Brown Switches' 'GX Blue, GX Brown, GX Red'
#  'Switch Mechanical (Brown, tactile)' 'Yes, Mechanical Switches' 'GATERON'
#  'Mechanical Switch' 'Blue Mechanical Switch'
#  'CONTENT Mechanical Blue/Brown/Red Switch (REMOVABLE)'
#  'Outemu / Gaote Blue' 'TTC Low Profile Mechanical Switch'
#  'Cherry MX compatible' 'Gateron Switches' 'Outemu box switch'
#  'Content Switch (Blue, Red, Brown)' 'Content Blue Clicky & Red Silent'
#  'Cherry MX, Gateron, Kailh, etc.' 'Outemu blue switch'
#  'Blue Switch/Brown Switch' 'MX-compatible' 'Cherry MX Red Switch'
#  'OUTEMU RED SWITCH' 'MX style' 'Hybrid Mechanical'
#  'Cherry MX blue switch' 'Kailh Box V2 Mechanical Switch'
#  'MX Blue, MX Red' 'Kailh Blue Switch'
#  'Romer-G Tactile or Linear Switches' 'Mechanical D-Switch'
#  'Phantom+ Orange/Brown/Pink/Red Pre-lubed Wraith Switches' 'Customizable'
#  'Cherry MX, Outemu, Gateron' 'Cherry MX, Outemu, Gateron, Kailh switches'
#  'Outemu Blue' 'Tecware Wraith Switches' 'USB Type C'
#  'Fantech Switches (Blue Switch, Red Switch)' 'Tecware Switch Sockets'
#  'Customizing options available' 'Cherry MX Compatible'
#  'GX Blue (Clicky), GX Brown (Tactile), GX Red (Linear)'
#  'Outemu Blue, Red, Brown Switch' 'Blue Switch (included)'
#  'Cherry MX, Gateron' 'Outemu Red switch equivalent' 'Cherry MX Blue'
#  'Cherry' 'Cherry MX Speed Silver' 'Cherry MX Black' 'Outemu 3-pin'
#  'Gateron CAP Milky Yellow (Linear), Kailh Box White (Clicky)'
#  'Kailh Blue Switch, Kailh Red Switch' 'Brown' 'OUTEMU Low Profile'
#  'Cherry MX Switch' 'Mechanical Brown Switches'
#  'Kailh Long Hua Blue switch' 'Kaihl LH Blue Switch'
#  'Low profile mechanical switch' 'Logitech GX' 'Membrane silent switch'
#  'Glacier Optical switches' 'MX switch' 'Cherry-style'
#  'Gamen Switch (blue)' 'Cherry MX BLUE Switches equivalent'
#  'Full Mechanical' 'MX stem compatible' 'Gateron Switch'
#  'Outemu Mechanical' 'Mechanical switches (Brown, tactile)'
#  'Kailh Box White Switches V2' 'Cherry profile' 'MX Style'
#  'A Level mechanical switch' 'Cherry MX, Outemu, Gateron, Etc'
#  'OTUM Red Switch' 'CHERRY MX' 'Short shaft mechanical switch'
#  'Kailh BOX Brown (Tactile) and BOX White (Clicky)' 'TTC Red Switch'
#  'HyperX mechanical gaming keyboards and most mechanical keyboards with a standard bottom row'
#  'Full key change shaft' 'Kailh Box White V2' 'Type-C USB'
#  'Switch options' 'Outemu Blue Switch/Red Switch' 'CHERRY MX switches'
#  'ROG NX mechanical switches' 'ROG NX Snow & Storm'
#  'Hybrid Blue Mechanical' 'Outemu switch 3 pin' 'Universal hotswap'
#  'Cherry Profile 3-Tone PBT Double Injection' 'GL Simple Switch'
#  'Gateron Switch (Yellow & Brown)' 'MX-Compatible Stem' 'PCB Mount'
#  'General' 'MX and BOX Switches' 'FR4 Fiber' 'Pluggable Mechanical Switch'
#  'Green shaft/black shaft/tea shaft/red shaft' 'Outemu GTMX'
#  'Universal 5 pin' 'Outemu Dustproof' 'Keychron K Pro Mechanical Switch'
#  'Kailh BOX White switches' 'MX mechanical switch'
#  'Content brand switches' 'ALPS, Buckling Spring, Cherry MX, Topre, etc.'
#  'Outemu switch' 'OUTEMO Blue switches'
#  'JWK Ultimate Black / Gateron Pro Yellow V.2 / Kailh Box White'
#  'MX Compatible' 'KRGD Blue Switch' 'Red Switch Outemu'
#  'Gateron, Cherry, Kailh, 5 Pin' 'Tactile Switch' 'Mechanical switch'
#  'MX-compatible Plate' 'Content' 'Gateron G Pro' 'Cherry MX RED SW'
#  'V3 Pro Yellow Switch (Linear)' 'Outemu Red/Brown/Blue' 'Cherry MX style'
#  'Universal 5 Pin Switch' 'Cherry MX-style' 'KRGD Blue Switch switches'
#  'KTT White / KTT Ash Grey' 'Gateron Mechanical / Keychron Optical Switch'
#  'Low Profile Gateron Mechanical / Keychron Optical Switch'
#  'MX Mechanical' 'Kailh Box V2 Brown Switch' 'Kailh Box V2 Red Switch'
#  'Kailh Box V2 White Switch' 'Gateron Mechanical'
#  'Outemu Blue, Outemu Brown, KTT Kang White' 'Gateron G Phantom'
#  'Razer Green Mechanical Switches (Clicky)'
#  'KTT White (Linear) and KTT Ash Grey (Tactile)' 'GX Blue Clicky Switch'
#  'CHERRY, OUTEMU, GATERON, KALIH, HUANO' 'Brown Switch'
#  'Outemu, Gateron, Cherry, Kailh' 'Gateron Pro' 'Romer-G Key Switches'
#  'Tactile Mechanical' 'Barebone' 'Outemu Blue, Red & Brown'
#  'Huano switch 3 pin' 'Blue/Red Mechanical Switches'
#  'Various (Gateron, Cherry, Kailh)' 'Gateron, Cherry MX, Kailh, etc.'
#  'MX-style' 'SNK Switch (Blue, Brown, Red)' 'TTC Switch'
#  'MX-Compatible stem' 'Gateron Phantom' 'Outemu Hotswap Switch'
#  'GX mechanical switches' 'Green Axis' 'TTC Mechanical Switch'
#  'Cherry MX RGB: Red switch' 'Mechanical Feel' 'Kailh, Outemu'
#  'Outemu GTMX Removable Switch' 'Outemu brown switch'
#  'Cherry MX Low Profile RGB' 'MSI Sonic Blue Switches'
#  'Linear Optical Switches Gen-2' 'CHERRY MX mechanical keyswitches'
#  'ROG NX Mechanical Switch'
#  'Razer Green Mechanical Switch, Razer Yellow Mechanical Switch'
#  'Gateron Cap Milky Yellow Switch (Linear Switch Sound Level Quiet) / Brown Switch, Kailh Box White Switch (Clicky Switch Sound Level Quiet) / Blue Switch'
#  'OmniPoint Adjustable Mechanical' 'Kaihl LH Switches'
#  'Razer Yellow, Razer Green' 'ROG NX Snow & Storm mechanical switches'
#  'MX Cherry' 'Cherry MX style switches' 'Membrane Mechanical Feel'
#  'ROG NX Mechanical Switches'
#  'Razer Yellow Mechanical Switches (Linear), Razer Green Mechanical Switches (Tactile)'
#  'ROG RX RED Optical Mechanical Switch' 'User-swappable'
#  'OmniPoint Adjustable Mechanical Switch' 'ROG NX Brown'
#  'SteelSeries QX2 Mechanical RGB Switch' 'Cherry MX RGB'
#  'Hybrid Mechanical RGB Switch' 'GL Clicky, GL Tactile, GL Linear'
#  'Semi-Mechanical' 'Varmilo EC Switches' 'Cherry MX stems'
#  'Romer-G Tactile Key Switches' 'Cherry MX switches'
#  'Cherry MX Low Profile RGB Speed Silver' 'OmniPoint Adjustable Switches'
#  'Razer Linear Optical Switch' 'Gateron Yellow'
#  'Cherry MX / Kailh / Gateron / Razer'
#  'Blue Kaihl Switches Mechanical Keyboard' 'Rapoo Blue switch'
#  'Kailh Blue Switches' 'Plate Mount' 'Blue, Black, Brown, Red'
#  'Kailh Red switches' 'Cherry MX / Kailh / Gateron'
#  'Linear Red, Tactile Brown, Clicky Blue'
#  'Night Breeze, Rose Glacier, Baby Raccoon, Baby Kangaroo, G Pro Red 2.0, G Pro Brown 2.0'
#  'GX Red Linear' 'Razer Yellow Mechanical Switches'
#  'MX and MX clone switches' '3 and 5 PIN' '60%' 'MX Switch + BOX' 'Matias'
#  'Cherry MX Mechanical Gaming Switch' 'OUTEMU Switches'
#  'Outemu Red switch' 'OUTEMU 3-pin switches' 'Mechanical switches'
#  'OUTEMU red switches' 'OUTEMU Low Profile Red Switches'
#  'OUTEMU BLUE SWITCH' 'Redragon switches' 'MX1 Legionare, MX 1 PR'
#  'Cherry MX Blue equivalent' 'Blue switches' 'Mechanical Switches'
#  'Outemu Red/Brown/Blue Switch (also supports Gateron Socket)'
#  'Ice silver transparent linear/Black transparent'
#  'Cherry MX Red equivalent' 'MX switches'
#  'Compatible with nearly all switches' 'MX style structure'
#  'Linear Red Switch' 'Cherry MX, Outemu' 'Yes (Brown switches)'
#  'Redragon Mechanical Blue Switches' 'Optic switch' 'Every Switch'
#  'Red mechanical switches' 'OUTEMU Blue Switch'
#  'OUTEMU Blue LK optical mechanical switches' 'OUTEMU Red Switch'
#  'Razer Green Mechanical Switch' 'Universal Hotswappable'
#  'Aukey Blue Switch' 'Outemu modular BLUE' 'Bloody BLMS Switch'
#  'Cherry MX & Cherry M8' 'Blue Mechanical switch' 'Unknown'
#  'OUTEMU ULTRA LOW RED SWITCH'
#  'GX Blue Clicky, Red Linear, GX Brown Tactile'
#  'Gateron Yellow Switch, Gateron Brown Switch'
#  'Razer Green Mechanical Switch / Razer Yellow Mechanical Switch'
#  'Razer Green, Razer Yellow'
#  'Night breeze, Rose glacier, BBK, BBR, G-Pro 2.0'
#  'Razer Mechanical Switch' 'Zorro' 'Cherry/OEM Profile'
#  'KAILH [Blue Switch]' 'Kaihl Blue Switch' 'MX Switch' 'Mechanical'
#  'TTC Mechanical Switch (Red)' 'Outemo Switch'
#  'Mechanical Black, Mechanical Brown, Mechanical Blue, Mechanical Red'
#  'Customized Linear Switch' 'Compatible with 3 and 5 PIN'
#  'Blue/Red Switch' 'Category' 'Cherry MX blue'
#  'Compatible with Fantech Keyboards, and most Keyboard Mechanicals'
#  'Gateron Switch Yellow and brown' 'Cherry MX switch' 'Blue'
#  'Red & Brown Outemu, Blueswitch Bsun'
#  'ROG RX Optical Mechanical Switches' 'OUTEMU Blue and Red'
#  'MAXFIT Switch (Milky Brown & Yellow)' 'Cherry MX Speed' 'Red/Brown'
#  'CHERRY MX SPEED' 'Gateron Switch (Red, Brown, Blue, Yellow)'
#  'GX Brown Tactile' 'HyperX Aqua Switch (Tactile)'
#  'HyperX Red Switch Linear' 'GX Red, GX Brown'
#  'CHERRY MX SPEED, CORSAIR OPX'
#  'German-made Cherry MX RGB mechanical switches'
#  'HyperX Aqua Switch Tactile' 'Razer Green/Yellow Mechanical Switch'
#  'Cherry MX RGB Silent, Cherry MX RGB Red, Cherry MX RGB Brown, Cherry MX RGB Blue'
#  'Cherry Viola' 'CherryMX' 'Gateron Socket' 'Green and Yellow'
#  'Gateron G-Pro V2/Baby Kangaroo switches' 'Outemu Brown' '3 pin & 5 pin'
#  'Razer Green / Yellow Mechanical Switch' 'Kailh MX Jellyfish Switch'
#  'Kailh Deep Sea Switches' 'MX style switch' 'Equivalent' 'Mechnanical'
#  'Gateron, JWick T1' 'Custom HyperX mechanical switches'
#  'Brown Switch, Rose Switch'
#  'G Red 2.0, G Blue 2.0, G Brown 2.0, Aloe (L37), Daisy (L48), Wisteria (T55)'
#  'MX style mechanical switches' 'HyperX mechanical switches'
#  'GX Blue Clicky' 'Kailh Low Profile Switches' 'MX 3-pin socket'
#  'ALPS-like' 'Outemu Low-profile Switch' 'Kaihl' 'Purple Switch'
#  'Kailh & -' 'Zorro blue switch' 'TKL'
#  'Gateron Pro Milky Yellow/Red, JWK T1 (Blue)' 'Romer-G Mechanical Switch'
#  'Cherry MX Blue, Cherry MX Brown' 'Gateron Optical Black/Blue/Brown/Red'
#  'Outemu CIY Switch' 'Cherry MX Style' 'Kailh MX Switches'
#  'OUTEMU Red Linear Switches' 'Kailh Blue' 'Kailh keys'
#  'Blue and Red switch' 'CHERRY MX RED' 'Kailh LH Blue Switch'
#  'ROG NX Snow and NX Storm'
#  'Gateron PRO v2 Yellow, Gateron PRO v2 Brown, AFLION Shadow, KTT Orange, Silent Grey'
#  '3 and 5 pin' '3 pins or 5 pins' 'ROG NX Mechanical'
#  'Outemu Blue, Swappable 3 pin switch' 'HyperX Switch'
#  'Cherry MX RGB Red Switches' 'Optical Mechanical Switches' 'Futaba MA'
#  'MX style switches (Red, Blue, Brown)' 'Alps White' 'Acer Switch'
#  'Blue Outemu' 'Kailh Speed Bronze' 'Red Switches'
#  'MX Mechanical Mini Tactile Quiet switch' 'Tactile Quiet'
#  'Keycap + Switch not included' 'Cherry MX Blue Switch'
#  'CK721, MK721, CK720 Series, SK600 Series, Most Type C Keyboards'
#  'Cherry MX / Gateron / TTC' 'Keychron Mechanical' 'KPT blue switch'
#  'Acer switch, Alps SKCM' 'Omron B3G-S series' 'Cherry MX RGB Red'
#  'TNT Switch' 'Keychron mechanical'
#  'Outemu Red/Brown/Blue Switch, Gateron Socket'
#  'Red linear optical switch' 'Blue/Brown/Red' 'HyperX Red - Linear'
#  'Kailh and MX' 'Blue Clicky'
#  'Gateron / Optical / Low profile Gateron mechanical / Low profile Keychron Optical'
#  'Kailh Low Profile White Clicky' 'OUTEMU Red Linear switches'
#  'Gateron, Cherry, Kailh, 5 pin switches'
#  'Switch Outemu (Blue, Brown, Red)' 'Cherry MX BLUE'
#  'Outemu (Blue, Brown, Red)' 'MX compatible' '1ST G switch (blue switch)'
#  'Kailh switches' 'Red, Blue, Black, Brown']

# %%
len(unique_compatibility_mech_swith)
# Out:
# 474

# %%
df['Compatibility with mechanical switch (Category)'] = df['Compatibility with mechanical switch (Category)'].replace({'Yes': '-', 'No': '-'})

# %%
unique_magic_fn = df['Magic FN key (Yes/No)'].unique()
print(unique_magic_fn)
# Out:
# ['No' 'Yes' '-' 'Yes (Hold FN+L_alt+L)']

# %%
df['Magic FN key (Yes/No)'] = df['Magic FN key (Yes/No)'].replace('Yes (Hold FN+L_alt+L)','Yes')

# %%
unique_magic_fn = df['Magic FN key (Yes/No)'].unique()
print(unique_magic_fn)
# Out:
# ['No' 'Yes' '-']

# %%
unique_soft_custome = df['Software customization (Yes/No)'].unique()
print(unique_soft_custome)
# Out:
# ['Yes' 'No' '-' 'Cooler Master MasterPlus+' 'Razer Synapse 3 enabled'
#  'QMK & VIA' 'Yes (VIA)' 'Cooler Master MasterPlus+ Software'
#  'Razer Synapse enabled' 'HERA Software' 'Yes (Cooler Master MasterPlus+)'
#  'Armoury Crate' 'Yes (Armoury Crate)' 'Yes (Razer Synapse)'
#  'SteelSeries Engine 3.15+ (coming soon)' 'Support VIA'
#  'Yes - 8BitDo Ultimate Software V2'
#  'Logitech Options for Windows 10 or later, Logitech Options for macOS 10.8 or later, Logitech Flow'
#  'Yes (QMK/VIA)' 'Logi Options+' 'Pro Driver Support' 'QMK/VIA support']

# %%
df['Software customization (Yes/No)'] = df['Software customization (Yes/No)'].apply(lambda x: 'Yes' if x not in ['No', '-'] else x)

# %%
unique_soft_custome = df['Software customization (Yes/No)'].unique()
print(unique_soft_custome)
# Out:
# ['Yes' 'No' '-']

# %%
df.to_csv('test-4.csv', index=False)

# %%
df = pd.read_csv('test-4.csv')
df
# Out:
#                                                   Title  Reviews  Sold
# 0     Keyboard Gaming Mechanical Rexus MX9 TKL Legio...        0   0.0  \
# 1     Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...        0   0.0
# 2     PXN K30 Gaming TKL Battledock Mechanical Keybo...        0   0.0
# 3     Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...        0   0.0
# 4     Gamen GMK01 PBT Keycaps - keycaps Mechanical k...        0   0.0
# ...                                                 ...      ...   ...
# 1816  BEST SELLER 1STPLAYER Mechanical Gaming Keyboa...        0   0.0
# 1817  PROMO Powerlogic Armageddon MKA 9C RGB Mechani...        0   0.0
# 1818  Terunik Powerlogic Armageddon MKA 5R RGB Mecha...        0   0.0
# 1819  Terunik Powerlogic Armageddon MKA 11R RGB Mech...        0   0.0
# 1820  BEST SELLER Cougar Mechanical Gaming Keyboard ...        0   0.0
#
#       Original Price             Store Name      Store City
# 0             549000             uneed shop   Jakarta Utara  \
# 1            1049000          Gaming Distro   Jakarta Pusat
# 2             538700          Store Pinokio  Kab. Tangerang
# 3             518400  Distributor_Aksesoris   Jakarta Pusat
# 4              79000               Starcomp          Sleman
# ...              ...                    ...             ...
# 1816         1425000                 Nelson   Jakarta Barat
# 1817         1185000                 Nelson   Jakarta Barat
# 1818         1440000                 Nelson   Jakarta Barat
# 1819         1612500                 Nelson   Jakarta Barat
# 1820         1320000                 Nelson   Jakarta Barat
#
#                                             Description Order Processing
# 0     Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1     Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2     Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3     POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4     Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
# ...                                                 ...              ...
# 1816  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1817  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1818  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1819  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1820  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
#
#       Positive Feedback  Total Feedback  ... Dimensions (Width) (millimeters)
# 0                  6516            6541  ...                            133.5  \
# 1                  1216            1275  ...                            126.0
# 2                  3132            3136  ...                            102.0
# 3                  4253            4479  ...                            103.0
# 4                  5693            5940  ...                                -
# ...                 ...             ...  ...                              ...
# 1816                  3               6  ...                              230
# 1817                  3               6  ...                                -
# 1818                  3               6  ...                              146
# 1819                  3               6  ...                                -
# 1820                  3               6  ...                              445
#
#      Dimensions (Height) (millimeters) Weight (grams)
# 0                                 22.5          950.0  \
# 1                                 41.5          800.0
# 2                                 40.0              -
# 3                                 42.0          566.0
# 4                                    -              -
# ...                                ...            ...
# 1816                                45           1400
# 1817                                 -              -
# 1818                                38              -
# 1819                                 -              -
# 1820                                40              -
#
#      Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0                               No                           No  \
# 1                               No                           No
# 2                               No                           No
# 3                              Yes                          Yes
# 4                                -                            -
# ...                            ...                          ...
# 1816                            No                           No
# 1817                            No                           No
# 1818                            No                           No
# 1819                            No                           No
# 1820                            No                           No
#
#      Detachable Type-C (Yes/No) Onboard memory (Yes/No)
# 0                            No                     Yes  \
# 1                           Yes                      No
# 2                           Yes                      No
# 3                           Yes                     Yes
# 4                             -                       -
# ...                         ...                     ...
# 1816                         No                      No
# 1817                         No                      No
# 1818                         No                      No
# 1819                         No                     Yes
# 1820                         No                      No
#
#      Anti-ghosting (Yes/No) RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                       Yes                   No                      -
# 1                       Yes                  Yes                   3750
# 2                       Yes                   No                   1850
# 3                       Yes                  Yes                      -
# 4                         -                    -                      -
# ...                     ...                  ...                    ...
# 1816                    Yes                   No                      -
# 1817                    Yes                   No                      -
# 1818                    Yes                   No                      -
# 1819                    Yes                   No                      -
# 1820                    Yes                  Yes                      -
#
# [1821 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Title', 'Reviews', 'Sold', 'Original Price', 'Store Name',
#        'Store City', 'Description', 'Order Processing', 'Positive Feedback',
#        'Total Feedback', 'Product URL', 'Brand (Category)',
#        'Material casing (Category)', 'Underglow RGB (Yes/No)',
#        'South-facing RGB switch (Yes/No)', 'Hot-swappable (5 pin) (Yes/No)',
#        'Compatibility with mechanical switch (Category)',
#        'Magic FN key (Yes/No)', 'Software customization (Yes/No)',
#        'Keycap profile (Category)', 'Color options (Category)',
#        'Switch options (Category)', 'Keyboard layout (Category)',
#        'Number of keys (Number)', 'Dimensions (Length) (millimeters)',
#        'Dimensions (Width) (millimeters)', 'Dimensions (Height) (millimeters)',
#        'Weight (grams)', 'Pre-lubed stabilizer (Yes/No)',
#        'Include damper foam (Yes/No)', 'Detachable Type-C (Yes/No)',
#        'Onboard memory (Yes/No)', 'Anti-ghosting (Yes/No)',
#        'RGB Per-Key (Yes/No)', 'Battery capacity (mAh)'],
#       dtype='object')

# %%
last_columns = ['Pre-lubed stabilizer (Yes/No)',
       'Include damper foam (Yes/No)', 'Detachable Type-C (Yes/No)',
       'Onboard memory (Yes/No)', 'Anti-ghosting (Yes/No)',
       'RGB Per-Key (Yes/No)']

# %%
for columns in last_columns:
    unique_data = df[columns].unique()
    print(columns)
    print(unique_data)
    print('----------------------')
# Out:
# Pre-lubed stabilizer (Yes/No)
# ['No' 'Yes' '-' 'Cherry screw-in stabilizers']
# ----------------------
# Include damper foam (Yes/No)
# ['No' 'Yes' '-'
#  'Poron Plate Foam, IXPE Switch Pad, PCBA, Poron Case Foam, VHB Insulation Layer, Extra Tape Mod, Extra Teflon Pads']
# ----------------------
# Detachable Type-C (Yes/No)
# ['No' 'Yes' '-']
# ----------------------
# Onboard memory (Yes/No)
# ['Yes' 'No' '-'
#  'Hybrid On-Board Memory and Cloud Storage up to 5 profiles'
#  'Hybrid onboard storage up to 5 profiles'
#  'Yes (Hybrid onboard storage up to 5 profiles)'
#  'Hybrid onboard storage up to 5 keybinding profiles']
# ----------------------
# Anti-ghosting (Yes/No)
# ['Yes' '-' '26 Keys' 'No' 'All Key' 'Full key anti-ghosting'
#  'Yes (68 keys)' '6-key rollover anti-ghosting' 'Full' 'N Key Rollover'
#  'Not specified' 'Full Keys Anti-Ghosting' 'N-Key Rollover' 'Yes (NKRO)'
#  'N-Key rollover']
# ----------------------
# RGB Per-Key (Yes/No)
# ['No' 'Yes' '-' 'There are 20 different backlight options' 'Unknown'
#  'Rainbow backlighting']
# ----------------------

# %%
for columns in last_columns:
    df[columns] = df[columns].apply(lambda x: 'Yes' if x not in ['No', '-'] else x)

# %%
for columns in last_columns:
    unique_data = df[columns].unique()
    print(columns)
    print(unique_data)
    print('----------------------')
# Out:
# Pre-lubed stabilizer (Yes/No)
# ['No' 'Yes' '-']
# ----------------------
# Include damper foam (Yes/No)
# ['No' 'Yes' '-']
# ----------------------
# Detachable Type-C (Yes/No)
# ['No' 'Yes' '-']
# ----------------------
# Onboard memory (Yes/No)
# ['Yes' 'No' '-']
# ----------------------
# Anti-ghosting (Yes/No)
# ['Yes' '-' 'No']
# ----------------------
# RGB Per-Key (Yes/No)
# ['No' 'Yes' '-']
# ----------------------

# %% [markdown]
# **Handling Missing Values:** We handle missing values in different columns, filling them with appropriate values or NaN where necessary.

# %%
df["Number of keys (Number)"] = pd.to_numeric(df["Number of keys (Number)"], errors='coerce').fillna(0).astype(int)

df["Battery capacity (mAh)"] = pd.to_numeric(df["Battery capacity (mAh)"], errors='coerce').fillna(0).astype(int)

df["Weight (grams)"] = pd.to_numeric(df["Weight (grams)"], errors='coerce').fillna(0).astype(float)

# Konversi kolom "Dimensions (Length) (millimeters)" menjadi tipe data float
df["Dimensions (Length) (millimeters)"] = pd.to_numeric(df["Dimensions (Length) (millimeters)"], errors='coerce').fillna(0).astype(float)

# Konversi kolom "Dimensions (Width) (millimeters)" menjadi tipe df float
df["Dimensions (Width) (millimeters)"] = pd.to_numeric(df["Dimensions (Width) (millimeters)"], errors='coerce').fillna(0).astype(float)

# Konversi kolom "Dimensions (Height) (millimeters)" menjadi tipe df float
df["Dimensions (Height) (millimeters)"] = pd.to_numeric(df["Dimensions (Height) (millimeters)"], errors='coerce').fillna(0).astype(float)

# %%
df.loc[:, df.dtypes == 'object'] = df.loc[:, df.dtypes == 'object'].replace('-', pd.NA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1821 entries, 0 to 1820
# Data columns (total 35 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Title                                            1821 non-null   object
#  1   Reviews                                          1821 non-null   int64
#  2   Sold                                             1821 non-null   float64
#  3   Original Price                                   1821 non-null   int64
#  4   Store Name                                       1821 non-null   object
#  5   Store City                                       1821 non-null   object
#  6   Description                                      1821 non-null   object
#  7   Order Processing                                 1802 non-null   object
#  8   Positive Feedback                                1821 non-null   int64
#  9   Total Feedback                                   1821 non-null   int64
#  10  Product URL                                      1821 non-null   object
#  11  Brand (Category)                                 1807 non-null   object
#  12  Material casing (Category)                       1292 non-null   object
#  13  Underglow RGB (Yes/No)                           1799 non-null   object
#  14  South-facing RGB switch (Yes/No)                 1578 non-null   object
#  15  Hot-swappable (5 pin) (Yes/No)                   1713 non-null   object
#  16  Compatibility with mechanical switch (Category)  1299 non-null   object
#  17  Magic FN key (Yes/No)                            1680 non-null   object
#  18  Software customization (Yes/No)                  1708 non-null   object
#  19  Keycap profile (Category)                        774 non-null    object
#  20  Color options (Category)                         1026 non-null   object
#  21  Switch options (Category)                        1300 non-null   object
#  22  Keyboard layout (Category)                       1072 non-null   object
#  23  Number of keys (Number)                          1821 non-null   int32
#  24  Dimensions (Length) (millimeters)                1821 non-null   float64
#  25  Dimensions (Width) (millimeters)                 1821 non-null   float64
#  26  Dimensions (Height) (millimeters)                1821 non-null   float64
#  27  Weight (grams)                                   1821 non-null   float64
#  28  Pre-lubed stabilizer (Yes/No)                    1555 non-null   object
#  29  Include damper foam (Yes/No)                     1513 non-null   object
#  30  Detachable Type-C (Yes/No)                       1691 non-null   object
#  31  Onboard memory (Yes/No)                          1695 non-null   object
#  32  Anti-ghosting (Yes/No)                           1682 non-null   object
#  33  RGB Per-Key (Yes/No)                             1750 non-null   object
#  34  Battery capacity (mAh)                           1821 non-null   int32
# dtypes: float64(5), int32(2), int64(4), object(24)
# memory usage: 483.8+ KB

# %%
# Ganti nilai 0 dengan NaN pada kolom yang dimaksud
cols_to_replace = ['Number of keys (Number)', 'Dimensions (Length) (millimeters)', 'Dimensions (Width) (millimeters)', 
                   'Dimensions (Height) (millimeters)', 'Weight (grams)', 'Battery capacity (mAh)']
df[cols_to_replace] = df[cols_to_replace].replace(0, pd.NA)

# %%
df.to_csv('mechanical-keyboard-cleaned-ready.csv', index= False)

# %% [markdown]
# **Adding IDs:** We add unique product IDs and store IDs to the dataframe to facilitate further analysis and database organization.

# %%
# Tambahkan kolom ID dengan nomor urutan di paling kiri DataFrame
df.insert(0, 'product_id', range(1, len(df) + 1))

# %%
df
# Out:
#       product_id                                              Title  Reviews
# 0              1  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...        0  \
# 1              2  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...        0
# 2              3  PXN K30 Gaming TKL Battledock Mechanical Keybo...        0
# 3              4  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...        0
# 4              5  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...        0
# ...          ...                                                ...      ...
# 1816        1817  BEST SELLER 1STPLAYER Mechanical Gaming Keyboa...        0
# 1817        1818  PROMO Powerlogic Armageddon MKA 9C RGB Mechani...        0
# 1818        1819  Terunik Powerlogic Armageddon MKA 5R RGB Mecha...        0
# 1819        1820  Terunik Powerlogic Armageddon MKA 11R RGB Mech...        0
# 1820        1821  BEST SELLER Cougar Mechanical Gaming Keyboard ...        0
#
#       Sold  Original Price             Store Name      Store City
# 0      0.0          549000             uneed shop   Jakarta Utara  \
# 1      0.0         1049000          Gaming Distro   Jakarta Pusat
# 2      0.0          538700          Store Pinokio  Kab. Tangerang
# 3      0.0          518400  Distributor_Aksesoris   Jakarta Pusat
# 4      0.0           79000               Starcomp          Sleman
# ...    ...             ...                    ...             ...
# 1816   0.0         1425000                 Nelson   Jakarta Barat
# 1817   0.0         1185000                 Nelson   Jakarta Barat
# 1818   0.0         1440000                 Nelson   Jakarta Barat
# 1819   0.0         1612500                 Nelson   Jakarta Barat
# 1820   0.0         1320000                 Nelson   Jakarta Barat
#
#                                             Description Order Processing
# 0     Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1     Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2     Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3     POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4     Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
# ...                                                 ...              ...
# 1816  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1817  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1818  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1819  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1820  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
#
#       Positive Feedback  ...  Dimensions (Width) (millimeters)
# 0                  6516  ...                             133.5  \
# 1                  1216  ...                             126.0
# 2                  3132  ...                             102.0
# 3                  4253  ...                             103.0
# 4                  5693  ...                              <NA>
# ...                 ...  ...                               ...
# 1816                  3  ...                             230.0
# 1817                  3  ...                              <NA>
# 1818                  3  ...                             146.0
# 1819                  3  ...                              <NA>
# 1820                  3  ...                             445.0
#
#      Dimensions (Height) (millimeters) Weight (grams)
# 0                                 22.5          950.0  \
# 1                                 41.5          800.0
# 2                                 40.0           <NA>
# 3                                 42.0          566.0
# 4                                 <NA>           <NA>
# ...                                ...            ...
# 1816                              45.0         1400.0
# 1817                              <NA>           <NA>
# 1818                              38.0           <NA>
# 1819                              <NA>           <NA>
# 1820                              40.0           <NA>
#
#      Pre-lubed stabilizer (Yes/No) Include damper foam (Yes/No)
# 0                               No                           No  \
# 1                               No                           No
# 2                               No                           No
# 3                              Yes                          Yes
# 4                             <NA>                         <NA>
# ...                            ...                          ...
# 1816                            No                           No
# 1817                            No                           No
# 1818                            No                           No
# 1819                            No                           No
# 1820                            No                           No
#
#      Detachable Type-C (Yes/No) Onboard memory (Yes/No)
# 0                            No                     Yes  \
# 1                           Yes                      No
# 2                           Yes                      No
# 3                           Yes                     Yes
# 4                          <NA>                    <NA>
# ...                         ...                     ...
# 1816                         No                      No
# 1817                         No                      No
# 1818                         No                      No
# 1819                         No                     Yes
# 1820                         No                      No
#
#      Anti-ghosting (Yes/No) RGB Per-Key (Yes/No) Battery capacity (mAh)
# 0                       Yes                   No                   <NA>
# 1                       Yes                  Yes                   3750
# 2                       Yes                   No                   1850
# 3                       Yes                  Yes                   <NA>
# 4                      <NA>                 <NA>                   <NA>
# ...                     ...                  ...                    ...
# 1816                    Yes                   No                    NaN
# 1817                    Yes                   No                    NaN
# 1818                    Yes                   No                    NaN
# 1819                    Yes                   No                    NaN
# 1820                    Yes                  Yes                    NaN
#
# [1821 rows x 36 columns]

# %%
store_id_map = {}
unique_id = 1
for store in df['Store Name'].unique():
    store_id_map[store] = unique_id
    unique_id += 1

# Buat kolom store_id berdasarkan kamus yang telah dibuat
df['store_id'] = df['Store Name'].map(store_id_map)

# %%
df
# Out:
#       product_id                                              Title  Reviews
# 0              1  Keyboard Gaming Mechanical Rexus MX9 TKL Legio...        0  \
# 1              2  Rexus Daxa M84 Ultimate Hotswap Wireless Mecha...        0
# 2              3  PXN K30 Gaming TKL Battledock Mechanical Keybo...        0
# 3              4  Fantech MK857 Maxfit61 Frost Wired RGB 60% Mec...        0
# 4              5  Gamen GMK01 PBT Keycaps - keycaps Mechanical k...        0
# ...          ...                                                ...      ...
# 1816        1817  BEST SELLER 1STPLAYER Mechanical Gaming Keyboa...        0
# 1817        1818  PROMO Powerlogic Armageddon MKA 9C RGB Mechani...        0
# 1818        1819  Terunik Powerlogic Armageddon MKA 5R RGB Mecha...        0
# 1819        1820  Terunik Powerlogic Armageddon MKA 11R RGB Mech...        0
# 1820        1821  BEST SELLER Cougar Mechanical Gaming Keyboard ...        0
#
#       Sold  Original Price             Store Name      Store City
# 0      0.0          549000             uneed shop   Jakarta Utara  \
# 1      0.0         1049000          Gaming Distro   Jakarta Pusat
# 2      0.0          538700          Store Pinokio  Kab. Tangerang
# 3      0.0          518400  Distributor_Aksesoris   Jakarta Pusat
# 4      0.0           79000               Starcomp          Sleman
# ...    ...             ...                    ...             ...
# 1816   0.0         1425000                 Nelson   Jakarta Barat
# 1817   0.0         1185000                 Nelson   Jakarta Barat
# 1818   0.0         1440000                 Nelson   Jakarta Barat
# 1819   0.0         1612500                 Nelson   Jakarta Barat
# 1820   0.0         1320000                 Nelson   Jakarta Barat
#
#                                             Description Order Processing
# 0     Rexus Keyboard Gaming Mechanical Legionare MX9...         ± 21 jam  \
# 1     Hi, Welcome to GAMING DISTRO - Authorized Deal...       ± 1-2 hari
# 2     Fitur:61 KEYS MINI KEYBOARD: Meskipun memperke...         ± 19 jam
# 3     POLYCARBONATE COVER & TRANSPARENT CASING + UND...         ± 15 jam
# 4     Keunggulan:Warna lucu desain manis senada deng...         ± 15 jam
# ...                                                 ...              ...
# 1816  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1817  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1818  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1819  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
# 1820  MOHON TANYAKAN TERLEBIH DAHULU UNTUK INFO STOK...       ± 1-2 hari
#
#       Positive Feedback  ...  Dimensions (Height) (millimeters)
# 0                  6516  ...                               22.5  \
# 1                  1216  ...                               41.5
# 2                  3132  ...                               40.0
# 3                  4253  ...                               42.0
# 4                  5693  ...                               <NA>
# ...                 ...  ...                                ...
# 1816                  3  ...                               45.0
# 1817                  3  ...                               <NA>
# 1818                  3  ...                               38.0
# 1819                  3  ...                               <NA>
# 1820                  3  ...                               40.0
#
#      Weight (grams) Pre-lubed stabilizer (Yes/No)
# 0             950.0                            No  \
# 1             800.0                            No
# 2              <NA>                            No
# 3             566.0                           Yes
# 4              <NA>                          <NA>
# ...             ...                           ...
# 1816         1400.0                            No
# 1817           <NA>                            No
# 1818           <NA>                            No
# 1819           <NA>                            No
# 1820           <NA>                            No
#
#      Include damper foam (Yes/No) Detachable Type-C (Yes/No)
# 0                              No                         No  \
# 1                              No                        Yes
# 2                              No                        Yes
# 3                             Yes                        Yes
# 4                            <NA>                       <NA>
# ...                           ...                        ...
# 1816                           No                         No
# 1817                           No                         No
# 1818                           No                         No
# 1819                           No                         No
# 1820                           No                         No
#
#      Onboard memory (Yes/No) Anti-ghosting (Yes/No) RGB Per-Key (Yes/No)
# 0                        Yes                    Yes                   No  \
# 1                         No                    Yes                  Yes
# 2                         No                    Yes                   No
# 3                        Yes                    Yes                  Yes
# 4                       <NA>                   <NA>                 <NA>
# ...                      ...                    ...                  ...
# 1816                      No                    Yes                   No
# 1817                      No                    Yes                   No
# 1818                      No                    Yes                   No
# 1819                     Yes                    Yes                   No
# 1820                      No                    Yes                  Yes
#
#      Battery capacity (mAh) store_id
# 0                      <NA>        1
# 1                      3750        2
# 2                      1850        3
# 3                      <NA>        4
# 4                      <NA>        5
# ...                     ...      ...
# 1816                    NaN      149
# 1817                    NaN      149
# 1818                    NaN      149
# 1819                    NaN      149
# 1820                    NaN      149
#
# [1821 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['product_id', 'Title', 'Reviews', 'Sold', 'Original Price',
#        'Store Name', 'Store City', 'Description', 'Order Processing',
#        'Positive Feedback', 'Total Feedback', 'Product URL',
#        'Brand (Category)', 'Material casing (Category)',
#        'Underglow RGB (Yes/No)', 'South-facing RGB switch (Yes/No)',
#        'Hot-swappable (5 pin) (Yes/No)',
#        'Compatibility with mechanical switch (Category)',
#        'Magic FN key (Yes/No)', 'Software customization (Yes/No)',
#        'Keycap profile (Category)', 'Color options (Category)',
#        'Switch options (Category)', 'Keyboard layout (Category)',
#        'Number of keys (Number)', 'Dimensions (Length) (millimeters)',
#        'Dimensions (Width) (millimeters)', 'Dimensions (Height) (millimeters)',
#        'Weight (grams)', 'Pre-lubed stabilizer (Yes/No)',
#        'Include damper foam (Yes/No)', 'Detachable Type-C (Yes/No)',
#        'Onboard memory (Yes/No)', 'Anti-ghosting (Yes/No)',
#        'RGB Per-Key (Yes/No)', 'Battery capacity (mAh)', 'store_id'],
#       dtype='object')

# %% [markdown]
# **Creating Separate DataFrames:** We create separate dataframes for stores and products, containing relevant information.

# %%
# Membuat DataFrame untuk tabel Stores
stores_df = df[['store_id', 'Store Name', 'Store City']].drop_duplicates().sort_values(by='store_id').copy()

# Menambahkan kolom tambahan ke DataFrame untuk tabel Stores
stores_df['Order Processing'] = df.groupby('store_id')['Order Processing'].max().values
stores_df['Positive Feedback'] = df.groupby('store_id')['Positive Feedback'].max().values
stores_df['Total Feedback'] = df.groupby('store_id')['Total Feedback'].max().values

# Membuat DataFrame untuk tabel Products
products_df = df.drop(columns=['store_id', 'Store Name', 'Store City', 'Order Processing', 'Positive Feedback', 'Total Feedback'])

# Menyimpan DataFrame ke file CSV
stores_df.to_csv('stores.csv', index=False)
products_df.to_csv('products.csv', index=False)

# %% [markdown]
# **Saving Cleaned Data:** Finally, we save the cleaned and prepared data into new CSV files for further analysis and usage.

# %%
df.to_csv('mechanical-keyboard-full.csv', index = False)
